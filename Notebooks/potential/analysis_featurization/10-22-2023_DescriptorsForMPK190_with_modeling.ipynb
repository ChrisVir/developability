# %% [markdown]
# ### Objective: To determine if doing de novo structure prediction helps with descriptors.
#
# Previously, I calculated descriptors for mutations of the MPK190 Ab and correlated this with Heparin Binding as measured by ELISA. This gave poor results. WHile, I beleive it is due to the assay, (which is still being developed in House), the poor correlation could be due to the method of creating muations. Here we construct all strucutres De Novo using ABBody Builder 2.
#
# Note that I ran this on my desktop and I have 2 seperate environments for doing structure prediction versus descriptor calcuation. Below is the code I used for the pytorch environment on my machine that I ran locally.

# %% [markdown]
# ```python
# import pandas as pd
# from ImmuneBuilder import ABodyBuilder2
# from pathlib import Path
# from tqdm.notebook import tqdm
#
# DATAPATH  = "/Users/ChristopherRivera/Documents/DataResults/MPK190"
# data_path = Path(DATAPATH)
#
# def predict_antibody_structures(sequences, output_dir=None):
#     """Given a dataframe with sequences, use ABodyBuilder2 model to predict sequences
#     Args:
#         sequence(pd.DataFrame|str|Path): data frame with columns 'Name', 'VH', 'VL'
#         output_dir(path|Str): location to save models.
#     Returns:
#         None
#     """
#
#     predictor = ABodyBuilder2()
#     if isinstance(sequences, str) or isinstance(sequences, Path):
#         sequences = pd.read_csv(sequences)
#     elif isinstance(sequences, pd.DataFrame):
#         pass
#     else:
#         print('Not antibodies')
#
#     sequences= sequences.dropna()
#     errors=[]
#
#     iterator = zip(sequences['Name'], sequences['VH'], sequences['VL'])
#     n = len(sequences)
#     for name, hc, lc in tqdm(iterator, total=n):
#         sequences = {'H': hc,'L': lc}
#         try:
#             antibody = predictor.predict(sequences)
#
#             if output_dir:
#                 output_file = output_dir/f'{name}.pdb'
#                 antibody.save(str(output_file))
#         except AssertionError:
#
#             errors.append(name)
#     return errors
#
#
# # load the data
# mutations_df = pd.read_parquet(data_path/'mutations_data.parquet')
# mutations_df = (mutations_df
#                 .drop_duplicates(subset = ['Vl mutations', 'Vh mutations'])
#                 .reset_index(drop=True)
#                 )
#
# # output path
# output_path = data_path/'predicted_pdbs'
# if not output_path.exists():
#     output_path.mkdir()
#
# def name_mutation(row):
#
#     vh = row['Vh mutations']
#     vl = row['Vl mutations']
#
#     name ='MPK190'
#     if vh:
#         vh = '_'.join(vh[1:-1].replace("'",'').replace(' ', '').split(','))
#         name += f'_VH_{vh}'
#
#     if vl:
#         vl = '_'.join(vl[1:-1].replace("'",'').replace(' ', '').split(','))
#         name += f'_VL_{vl}'
#
#     return name
#
# mutations_df['Name'] = mutations_df.apply(name_mutation, axis = 1)
# mutations_df = mutations_df.rename({'Vl': 'VL', 'Vh':'VH'}, axis = 1)
#
# errors = predict_antibody_structures(mutations_df, output_dir=output_path)
# ```

# %% [markdown]
# ##### Import Modules and set up paths.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from pathlib import Path
import matplotlib.pyplot as plt
from tqdm.notebook import tqdm 

from developability.utils import ls
from developability.pipeline import run_processing_pipeline

# %%
DATAPATH  = "/Users/ChristopherRivera/Documents/DataResults/MPK190"   # change this as needed
data_path = Path(DATAPATH)
predicted_pdb_path = data_path/'predicted_pdbs'
pdbs = [f for f in ls(predicted_pdb_path) if f.name.endswith('.pdb')]

# %%
descriptors_file = data_path/ 'descriptors_MPK190_predicted.pq'
if not descriptors_file.exists(): 
    descriptors = []

    for pdb in tqdm(pdbs, total = len(pdbs)): 
        descriptors.append(run_processing_pipeline(input_pdb=pdb))
    
    descriptors_df = pd.concat(descriptors)
    descriptors_df.to_parquet(descriptors_file)

else: 
    descriptors_df = pd.read_parquet(descriptors_file)
# Out:
#   0%|          | 0/141 [00:00<?, ?it/s]
# Starting pdb4amber with /Users/ChristopherRivera/Documents/DataResults/MPK190/predicted_pdbs/MPK190_VL_G43E_S69E.pdb.
#
# 2023-11-03 20:43:12,450 [MainThread  ] [INFO ]  Executing biobb_amber.pdb4amber.pdb4amber_run Version: 4.1.0
# 2023-11-03 20:43:12,451 [MainThread  ] [INFO ]  Copy: /Users/ChristopherRivera/Documents/DataResults/MPK190/predicted_pdbs/MPK190_VL_G43E_S69E.pdb to /Users/ChristopherRivera/Projects/developability/Notebooks/ae9ce31a-367d-4e1a-9f61-04a7da3d2fb6
# 2023-11-03 20:43:12,452 [MainThread  ] [INFO ]  Creating de54966a-8c3d-474f-917d-25a14d1d0e12 temporary folder
# 2023-11-03 20:43:12,452 [MainThread  ] [INFO ]  pdb4amber -i /Users/ChristopherRivera/Projects/developability/Notebooks/ae9ce31a-367d-4e1a-9f61-04a7da3d2fb6/MPK190_VL_G43E_S69E.pdb -o /Users/ChristopherRivera/Projects/developability/Notebooks/ae9ce31a-367d-4e1a-9f61-04a7da3d2fb6/pdb4amber.pdb -y
#
# 2023-11-03 20:43:13,148 [MainThread  ] [INFO ]  Exit code 0
#
# 2023-11-03 20:43:13,149 [MainThread  ] [INFO ]
# ==================================================
# Summary of pdb4amber for: /Users/ChristopherRivera/Projects/developability/Notebooks/ae9ce31a-367d-4e1a-9f61-04a7da3d2fb6/MPK190_VL_G43E_S69E.pdb
# ===================================================
#
# ----------Chains
# The following (original) chains have been found:
# H
# L
#
# ---------- Alternate Locations (Original Residues!))
#
# The following residues had alternate locations:
# None
# -----------Non-standard-resnames
#
#
# ---------- Missing heavy atom(s)
#
# None
#
# 2023-11-03 20:43:13,152 [MainThread  ] [INFO ]  Removed: ['/Users/ChristopherRivera/Projects/developability/Notebooks/ae9ce31a-367d-4e1a-9f61-04a7da3d2fb6', 'de54966a-8c3d-474f-917d-25a14d1d0e12']
# Finished pdb4amber.
#
# Starting Leap with /Users/ChristopherRivera/Documents/DataResults/MPK190/predicted_pdbs/MPK190_VL_G43E_S69E_outputs/pdb4amber.pdb.
#
# 2023-11-03 20:43:13,154 [MainThread  ] [INFO ]  Executing biobb_amber.leap.leap_gen_top Version: 4.1.0
# 2023-11-03 20:43:13,154 [MainThread  ] [INFO ]  Copy: /Users/ChristopherRivera/Documents/DataResults/MPK190/predicted_pdbs/MPK190_VL_G43E_S69E_outputs/pdb4amber.pdb to /Users/ChristopherRivera/Projects/developability/Notebooks/bf152400-3e98-4519-87c9-a18617286cb3
# 2023-11-03 20:43:13,155 [MainThread  ] [INFO ]  Creating 994e5e18-b02b-4472-9583-bbb7c0f90a10 temporary folder
# 2023-11-03 20:43:13,156 [MainThread  ] [INFO ]  tleap -f 994e5e18-b02b-4472-9583-bbb7c0f90a10/leap.in
#
# 2023-11-03 20:43:14,300 [MainThread  ] [INFO ]  Exit code 0
#
# 2023-11-03 20:43:14,301 [MainThread  ] [INFO ]  -I: Adding /Users/ChristopherRivera/micromamba/envs/surface/dat/leap/prep to search path.
# -I: Adding /Users/ChristopherRivera/micromamba/envs/surface/dat/leap/lib to search path.
# -I: Adding /Users/ChristopherRivera/micromamba/envs/surface/dat/leap/parm to search path.
# -I: Adding /Users/ChristopherRivera/micromamba/envs/surface/dat/leap/cmd to search path.
# -f: Source 994e5e18-b02b-4472-9583-bbb7c0f90a10/leap.in.
#
# Welcome to LEaP!
# (no leaprc in search path)
# Sourcing: ./994e5e18-b02b-4472-9583-bbb7c0f90a10/leap.in
# ----- Source: /Users/ChristopherRivera/micromamba/envs/surface/dat/leap/cmd/leaprc.protein.ff19SB
# ----- Source of /Users/ChristopherRivera/micromamba/envs/surface/dat/leap/cmd/leaprc.protein.ff19SB done
# Log file: ./leap.log
# Loading parameters: /Users/ChristopherRivera/micromamba/envs/surface/dat/leap/parm/parm19.dat
# Reading title:
# PARM99 + frcmod.ff99SB + frcmod.parmbsc0 + OL3 for RNA + ff19SB
# Loading parameters: /Users/ChristopherRivera/micromamba/envs/surface/dat/leap/parm/frcmod.ff19SB
# Reading force field modification type file (frcmod)
# Reading title:
# ff19SB AA-specific backbone CMAPs for protein 07/25/2019
# Loading library: /Users/ChristopherRivera/micromamba/envs/surface/dat/leap/lib/amino19.lib
# Loading library: /Users/ChristopherRivera/micromamba/envs/surface/dat/leap/lib/aminoct12.lib
# Loading library: /Users/ChristopherRivera/micromamba/envs/surface/dat/leap/lib/aminont12.lib
# Loading library: /Users/ChristopherRivera/micromamba/envs/surface/dat/leap/lib/atomic_ions.lib
# Loading PDB file: /Users/ChristopherRivera/Projects/developability/Notebooks/bf152400-3e98-4519-87c9-a18617286cb3/pdb4amber.pdb
#   Added missing heavy atom: .R<CGLY 9>.A<OXT 8>
#   Added missing heavy atom: .R<CILE 29>.A<OXT 20>
#   Added missing heavy atom: .R<CSER 54>.A<OXT 12>
#   Added missing heavy atom: .R<CLYS 65>.A<OXT 23>
#   Added missing heavy atom: .R<CGLU 102>.A<OXT 16>
#   Added missing heavy atom: .R<CSER 128>.A<OXT 12>
#   Added missing heavy atom: .R<CGLY 149>.A<OXT 8>
#   Added missing heavy atom: .R<CASN 172>.A<OXT 15>
#   Added missing heavy atom: .R<CPRO 180>.A<OXT 15>
#   Added missing heavy atom: .R<CASN 187>.A<OXT 15>
#   Added missing heavy atom: .R<CARG 215>.A<OXT 25>
#   total atoms in file: 1727
#   Leap added 1712 missing atoms according to residue templates:
#        11 Heavy
#        1701 H / lone pairs
# Writing pdb file: /Users/ChristopherRivera/Projects/developability/Notebooks/bf152400-3e98-4519-87c9-a18617286cb3/leap.pdb
#
# /Users/ChristopherRivera/micromamba/envs/surface/bin/teLeap: Warning!
#  Converting N-terminal residue name to PDB format: NGLN -> GLN
#
# /Users/ChristopherRivera/micromamba/envs/surface/bin/teLeap: Warning!
#  Converting C-terminal residue name to PDB format: CGLY -> GLY
#
# /Users/ChristopherRivera/micromamba/envs/surface/bin/teLeap: Warning!
#  Converting N-terminal residue name to PDB format: NGLY -> GLY
#
# /Users/ChristopherRivera/micromamba/envs/surface/bin/teLeap: Warning!
#  Converting C-terminal residue name to PDB format: CILE -> ILE
#
# /Users/ChristopherRivera/micromamba/envs/surface/bin/teLeap: Warning!
#  Converting N-terminal residue name to PDB format: NSER -> SER
#
# /Users/ChristopherRivera/micromamba/envs/surface/bin/teLeap: Warning!
#  Converting C-terminal residue name to PDB format: CSER -> SER
#
# /Users/ChristopherRivera/micromamba/envs/surface/bin/teLeap: Warning!
#  Converting N-terminal residue name to PDB format: NSER -> SER
#
# /Users/ChristopherRivera/micromamba/envs/surface/bin/teLeap: Warning!
#  Converting C-terminal residue name to PDB format: CLYS -> LYS
#
# /Users/ChristopherRivera/micromamba/envs/surface/bin/teLeap: Warning!
#  Converting N-terminal residue name to PDB format: NGLY -> GLY
#
# /Users/ChristopherRivera/micromamba/envs/surface/bin/teLeap: Warning!
#  Converting C-terminal residue name to PDB format: CGLU -> GLU
#
# /Users/ChristopherRivera/micromamba/envs/surface/bin/teLeap: Warning!
#  Converting N-terminal residue name to PDB format: NPRO -> PRO
#
# /Users/ChristopherRivera/micromamba/envs/surface/bin/teLeap: Warning!
#  Converting C-terminal residue name to PDB format: CSER -> SER
#
# /Users/ChristopherRivera/micromamba/envs/surface/bin/teLeap: Warning!
#  Converting N-terminal residue name to PDB format: NGLN -> GLN
#
# /Users/ChristopherRivera/micromamba/envs/surface/bin/teLeap: Warning!
#  Converting C-terminal residue name to PDB format: CSER -> SER
#
# /Users/ChristopherRivera/micromamba/envs/surface/bin/teLeap: Warning!
#  Converting N-terminal residue name to PDB format: NVAL -> VAL
#
# /Users/ChristopherRivera/micromamba/envs/surface/bin/teLeap: Warning!
#  Converting C-terminal residue name to PDB format: CGLY -> GLY
#
# /Users/ChristopherRivera/micromamba/envs/surface/bin/teLeap: Warning!
#  Converting N-terminal residue name to PDB format: NALA -> ALA
#
# /Users/ChristopherRivera/micromamba/envs/surface/bin/teLeap: Warning!
#  Converting C-terminal residue name to PDB format: CASN -> ASN
#
# /Users/ChristopherRivera/micromamba/envs/surface/bin/teLeap: Warning!
#  Converting N-terminal residue name to PDB format: NTHR -> THR
#
# /Users/ChristopherRivera/micromamba/envs/surface/bin/teLeap: Warning!
#  Converting C-terminal residue name to PDB format: CPRO -> PRO
#
# /Users/ChristopherRivera/micromamba/envs/surface/bin/teLeap: Warning!
#  Converting N-terminal residue name to PDB format: NASP -> ASP
#
# /Users/ChristopherRivera/micromamba/envs/surface/bin/teLeap: Warning!
#  Converting C-terminal residue name to PDB format: CASN -> ASN
#
# /Users/ChristopherRivera/micromamba/envs/surface/bin/teLeap: Warning!
#  Converting N-terminal residue name to PDB format: NGLU -> GLU
#
# /Users/ChristopherRivera/micromamba/envs/surface/bin/teLeap: Warning!
#  Converting C-terminal residue name to PDB format: CARG -> ARG
#
# /Users/ChristopherRivera/micromamba/envs/surface/bin/teLeap: Warning!
#  Converting N-terminal residue name to PDB format: NLEU -> LEU
#
# /Users/ChristopherRivera/micromamba/envs/surface/bin/teLeap: Warning!
#  Converting C-terminal residue name to PDB format: CLEU -> LEU
# Checking Unit.
#
# /Users/ChristopherRivera/micromamba/envs/surface/bin/teLeap: Warning!
# The unperturbed charge of the unit (2.000000) is not zero.
#
# /Users/ChristopherRivera/micromamba/envs/surface/bin/teLeap: Note.
# Ignoring the warning from Unit Checking.
#
# Building topology.
# Building atom parameters.
# Building bond parameters.
# Building angle parameters.
# Building proper torsion parameters.
# Building improper torsion parameters.
#  total 702 improper torsions applied
# Building H-Bond parameters.
# Incorporating Non-Bonded adjustments.
# Not Marking per-residue atom chain types.
# Marking per-residue atom chain types.
#   (Residues lacking connect0/connect1 -
#    these don't have chain types marked:
#
# 	res	total affected
#
# 	CARG	1
# 	CASN	2
# 	CGLU	1
# 	CGLY	2
# 	CILE	1
# 	CLEU	1
# 	CLYS	1
# 	CPRO	1
# 	CSER	3
# 	NALA	1
# 	NASP	1
# 	NGLN	2
# 	NGLU	1
# 	NGLY	2
# 	NLEU	1
# 	NPRO	1
# 	NSER	2
# 	NTHR	1
# 	NVAL	1
#   )
#  (no restraints)
# 	Quit
#
# Exiting LEaP: Errors = 0; Warnings = 27; Notes = 1.
#
# 2023-11-03 20:43:14,304 [MainThread  ] [INFO ]  Removed: ['/Users/ChristopherRivera/Projects/developability/Notebooks/bf152400-3e98-4519-87c9-a18617286cb3', '994e5e18-b02b-4472-9583-bbb7c0f90a10', 'leap.log']
# Finished Leap.
#
# Starting Sander with /Users/ChristopherRivera/Documents/DataResults/MPK190/predicted_pdbs/MPK190_VL_G43E_S69E_outputs/leap.pdb.
#
# 2023-11-03 20:43:14,306 [MainThread  ] [INFO ]  Executing biobb_amber.sander.sander_mdrun Version: 4.1.0
# 2023-11-03 20:43:14,307 [MainThread  ] [INFO ]  Copy: /Users/ChristopherRivera/Documents/DataResults/MPK190/predicted_pdbs/MPK190_VL_G43E_S69E_outputs/leap.top to /Users/ChristopherRivera/Projects/developability/Notebooks/2ed45afa-fbbf-44f3-911a-30a09e653544
# 2023-11-03 20:43:14,308 [MainThread  ] [INFO ]  Copy: /Users/ChristopherRivera/Documents/DataResults/MPK190/predicted_pdbs/MPK190_VL_G43E_S69E_outputs/leap.crd to /Users/ChristopherRivera/Projects/developability/Notebooks/2ed45afa-fbbf-44f3-911a-30a09e653544
# 2023-11-03 20:43:14,309 [MainThread  ] [INFO ]  Copy: /Users/ChristopherRivera/Documents/DataResults/MPK190/predicted_pdbs/MPK190_VL_G43E_S69E_outputs/leap.crd to /Users/ChristopherRivera/Projects/developability/Notebooks/2ed45afa-fbbf-44f3-911a-30a09e653544
# 2023-11-03 20:43:14,309 [MainThread  ] [INFO ]  Creating bb45a94e-7881-4db1-846a-d5ae39e51e9b temporary folder
# 2023-11-03 20:43:14,309 [MainThread  ] [INFO ]  sander -O -i bb45a94e-7881-4db1-846a-d5ae39e51e9b/sander.mdin -p /Users/ChristopherRivera/Projects/developability/Notebooks/2ed45afa-fbbf-44f3-911a-30a09e653544/leap.top -c /Users/ChristopherRivera/Projects/developability/Notebooks/2ed45afa-fbbf-44f3-911a-30a09e653544/leap.crd -r /Users/ChristopherRivera/Projects/developability/Notebooks/2ed45afa-fbbf-44f3-911a-30a09e653544/sander.rst -o /Users/ChristopherRivera/Projects/developability/Notebooks/2ed45afa-fbbf-44f3-911a-30a09e653544/sander.log -x /Users/ChristopherRivera/Projects/developability/Notebooks/2ed45afa-fbbf-44f3-911a-30a09e653544/sander.x -ref /Users/ChristopherRivera/Projects/developability/Notebooks/2ed45afa-fbbf-44f3-911a-30a09e653544/leap.crd
#
# 2023-11-03 20:43:19,706 [MainThread  ] [INFO ]  Exit code 0
#
# 2023-11-03 20:43:19,709 [MainThread  ] [INFO ]  Removed: ['/Users/ChristopherRivera/Projects/developability/Notebooks/2ed45afa-fbbf-44f3-911a-30a09e653544', 'mdinfo', 'bb45a94e-7881-4db1-846a-d5ae39e51e9b']
# 2023-11-03 20:43:19,709 [MainThread  ] [INFO ]  Path /Users/ChristopherRivera/Documents/DataResults/MPK190/predicted_pdbs/MPK190_VL_G43E_S69E_outputs/sander.x --- biobb_amber.sander.sander_mdrun: Unexisting output_traj_path file.
# Finished Sander.
#
# Converting Sander results to pdb.
#
# 2023-11-03 20:43:19,712 [MainThread  ] [INFO ]  Executing biobb_amber.ambpdb.amber_to_pdb Version: 4.1.0
# 2023-11-03 20:43:19,713 [MainThread  ] [INFO ]  Copy: /Users/ChristopherRivera/Documents/DataResults/MPK190/predicted_pdbs/MPK190_VL_G43E_S69E_outputs/leap.top to /Users/ChristopherRivera/Projects/developability/Notebooks/a8411c84-6d1c-43a4-8a19-2b51cfc7653f
# 2023-11-03 20:43:19,713 [MainThread  ] [INFO ]  Copy: /Users/ChristopherRivera/Documents/DataResults/MPK190/predicted_pdbs/MPK190_VL_G43E_S69E_outputs/sander.rst to /Users/ChristopherRivera/Projects/developability/Notebooks/a8411c84-6d1c-43a4-8a19-2b51cfc7653f
# 2023-11-03 20:43:19,714 [MainThread  ] [INFO ]  ambpdb -p /Users/ChristopherRivera/Projects/developability/Notebooks/a8411c84-6d1c-43a4-8a19-2b51cfc7653f/leap.top -c /Users/ChristopherRivera/Projects/developability/Notebooks/a8411c84-6d1c-43a4-8a19-2b51cfc7653f/sander.rst >  /Users/ChristopherRivera/Projects/developability/Notebooks/a8411c84-6d1c-43a4-8a19-2b51cfc7653f/MPK190_VL_G43E_S69E.energy_minimized.pdb
#
# 2023-11-03 20:43:19,876 [MainThread  ] [INFO ]  Exit code 0
#
# 2023-11-03 20:43:19,878 [MainThread  ] [INFO ]  Removed: ['/Users/ChristopherRivera/Projects/developability/Notebooks/a8411c84-6d1c-43a4-8a19-2b51cfc7653f']
# Finished conversion
#
# Starting pdb2pqr on MPK190_VL_G43E_S69E.energy_minimized.pdb
#
# Generating APBS ini file.
#
# Running APBS.
#
#  Writing data to flat file /Users/ChristopherRivera/Documents/DataResults/MPK190/predicted_pdbs/MPK190_VL_G43E_S69E_outputs/MPK190_VL_G43E_S69E.energy_minimized.pqr.log...
#
#
# Starting Nanoshaper on MPK190_VL_G43E_S69E.energy_minimized.xyzr file.
#
# Finished Nanoshaper, now creating coordinates.csv.
#
# Finished extracting xyz and atoms.
#
# Now extracting pertinent potential values using multivalue.
#
# /Users/ChristopherRivera/bioprograms/APBS-3.4.1.Darwin/share/apbs/tools/bin/multivalue /Users/ChristopherRivera/Documents/DataResults/MPK190/predicted_pdbs/MPK190_VL_G43E_S69E_outputs/triangulatedSurf.csv /Users/ChristopherRivera/Documents/DataResults/MPK190/predicted_pdbs/MPK190_VL_G43E_S69E_outputs/MPK190_VL_G43E_S69E.energy_minimized.pqr.dx /Users/ChristopherRivera/Documents/DataResults/MPK190/predicted_pdbs/MPK190_VL_G43E_S69E_outputs/potential_coordinates.csv
# Finished extracting potential values.
# Now mapping potential to individual atoms in  pqr_file.
#
# Finished mapping potentials to atoms.
# Now aggregating potentials over residues.
#
# Finished...
# Starting pdb4amber with /Users/ChristopherRivera/Documents/DataResults/MPK190/predicted_pdbs/MPK190_VL_S69E_A76S.pdb.
#
# 2023-11-03 20:43:28,571 [MainThread  ] [INFO ]  Executing biobb_amber.pdb4amber.pdb4amber_run Version: 4.1.0
# 2023-11-03 20:43:28,572 [MainThread  ] [INFO ]  Copy: /Users/ChristopherRivera/Documents/DataResults/MPK190/predicted_pdbs/MPK190_VL_S69E_A76S.pdb to /Users/ChristopherRivera/Projects/developability/Notebooks/2335f565-d90b-433e-baf9-b4907880562a
# 2023-11-03 20:43:28,573 [MainThread  ] [INFO ]  Creating a11390eb-5487-42e9-9e7c-573d823c0729 temporary folder
# 2023-11-03 20:43:28,573 [MainThread  ] [INFO ]  pdb4amber -i /Users/ChristopherRivera/Projects/developability/Notebooks/2335f565-d90b-433e-baf9-b4907880562a/MPK190_VL_S69E_A76S.pdb -o /Users/ChristopherRivera/Projects/developability/Notebooks/2335f565-d90b-433e-baf9-b4907880562a/pdb4amber.pdb -y
#
# 2023-11-03 20:43:29,056 [MainThread  ] [INFO ]  Exit code 0
#
# 2023-11-03 20:43:29,057 [MainThread  ] [INFO ]
# ==================================================
# Summary of pdb4amber for: /Users/ChristopherRivera/Projects/developability/Notebooks/2335f565-d90b-433e-baf9-b4907880562a/MPK190_VL_S69E_A76S.pdb
# ===================================================
#
# ----------Chains
# The following (original) chains have been found:
# H
# L
#
# ---------- Alternate Locations (Original Residues!))
#
# The following residues had alternate locations:
# None
# -----------Non-standard-resnames
#
#
# ---------- Missing heavy atom(s)
#
# None
#
# 2023-11-03 20:43:29,059 [MainThread  ] [INFO ]  Removed: ['/Users/ChristopherRivera/Projects/developability/Notebooks/2335f565-d90b-433e-baf9-b4907880562a', 'a11390eb-5487-42e9-9e7c-573d823c0729']
# Finished pdb4amber.
#
# Starting Leap with /Users/ChristopherRivera/Documents/DataResults/MPK190/predicted_pdbs/MPK190_VL_S69E_A76S_outputs/pdb4amber.pdb.
#
# 2023-11-03 20:43:29,061 [MainThread  ] [INFO ]  Executing biobb_amber.leap.leap_gen_top Version: 4.1.0
# 2023-11-03 20:43:29,062 [MainThread  ] [INFO ]  Copy: /Users/ChristopherRivera/Documents/DataResults/MPK190/predicted_pdbs/MPK190_VL_S69E_A76S_outputs/pdb4amber.pdb to /Users/ChristopherRivera/Projects/developability/Notebooks/ab8da1d0-838e-482c-9548-90d284b33fe9
# 2023-11-03 20:43:29,062 [MainThread  ] [INFO ]  Creating 45630182-1824-45d7-b4bc-cf1f261ccdad temporary folder
# 2023-11-03 20:43:29,063 [MainThread  ] [INFO ]  tleap -f 45630182-1824-45d7-b4bc-cf1f261ccdad/leap.in
#
# 2023-11-03 20:43:29,344 [MainThread  ] [INFO ]  Exit code 0
#
# 2023-11-03 20:43:29,345 [MainThread  ] [INFO ]  -I: Adding /Users/ChristopherRivera/micromamba/envs/surface/dat/leap/prep to search path.
# -I: Adding /Users/ChristopherRivera/micromamba/envs/surface/dat/leap/lib to search path.
# -I: Adding /Users/ChristopherRivera/micromamba/envs/surface/dat/leap/parm to search path.
# -I: Adding /Users/ChristopherRivera/micromamba/envs/surface/dat/leap/cmd to search path.
# -f: Source 45630182-1824-45d7-b4bc-cf1f261ccdad/leap.in.
#
# Welcome to LEaP!
# (no leaprc in search path)
# Sourcing: ./45630182-1824-45d7-b4bc-cf1f261ccdad/leap.in
# ----- Source: /Users/ChristopherRivera/micromamba/envs/surface/dat/leap/cmd/leaprc.protein.ff19SB
# ----- Source of /Users/ChristopherRivera/micromamba/envs/surface/dat/leap/cmd/leaprc.protein.ff19SB done
# Log file: ./leap.log
# Loading parameters: /Users/ChristopherRivera/micromamba/envs/surface/dat/leap/parm/parm19.dat
# Reading title:
# PARM99 + frcmod.ff99SB + frcmod.parmbsc0 + OL3 for RNA + ff19SB
# Loading parameters: /Users/ChristopherRivera/micromamba/envs/surface/dat/leap/parm/frcmod.ff19SB
# Reading force field modification type file (frcmod)
# Reading title:
# ff19SB AA-specific backbone CMAPs for protein 07/25/2019
# Loading library: /Users/ChristopherRivera/micromamba/envs/surface/dat/leap/lib/amino19.lib
# Loading library: /Users/ChristopherRivera/micromamba/envs/surface/dat/leap/lib/aminoct12.lib
# Loading library: /Users/ChristopherRivera/micromamba/envs/surface/dat/leap/lib/aminont12.lib
# Loading library: /Users/ChristopherRivera/micromamba/envs/surface/dat/leap/lib/atomic_ions.lib
# Loading PDB file: /Users/ChristopherRivera/Projects/developability/Notebooks/ab8da1d0-838e-482c-9548-90d284b33fe9/pdb4amber.pdb
#   Added missing heavy atom: .R<CGLY 9>.A<OXT 8>
#   Added missing heavy atom: .R<CILE 29>.A<OXT 20>
#   Added missing heavy atom: .R<CSER 54>.A<OXT 12>
#   Added missing heavy atom: .R<CLYS 65>.A<OXT 23>
#   Added missing heavy atom: .R<CGLU 102>.A<OXT 16>
#   Added missing heavy atom: .R<CSER 128>.A<OXT 12>
#   Added missing heavy atom: .R<CGLY 149>.A<OXT 8>
#   Added missing heavy atom: .R<CASN 172>.A<OXT 15>
#   Added missing heavy atom: .R<CPRO 180>.A<OXT 15>
#   Added missing heavy atom: .R<CASN 187>.A<OXT 15>
#   Added missing heavy atom: .R<CARG 215>.A<OXT 25>
#   total atoms in file: 1723
#   Leap added 1709 missing atoms according to residue templates:
#        11 Heavy
#        1698 H / lone pairs
# Writing pdb file: /Users/ChristopherRivera/Projects/developability/Notebooks/ab8da1d0-838e-482c-9548-90d284b33fe9/leap.pdb
#
# /Users/ChristopherRivera/micromamba/envs/surface/bin/teLeap: Warning!
#  Converting N-terminal residue name to PDB format: NGLN -> GLN
#
# /Users/ChristopherRivera/micromamba/envs/surface/bin/teLeap: Warning!
#  Converting C-terminal residue name to PDB format: CGLY -> GLY
#
# /Users/ChristopherRivera/micromamba/envs/surface/bin/teLeap: Warning!
#  Converting N-terminal residue name to PDB format: NGLY -> GLY
#
# /Users/ChristopherRivera/micromamba/envs/surface/bin/teLeap: Warning!
#  Converting C-terminal residue name to PDB format: CILE -> ILE
#
# /Users/ChristopherRivera/micromamba/envs/surface/bin/teLeap: Warning!
#  Converting N-terminal residue name to PDB format: NSER -> SER
#
# /Users/ChristopherRivera/micromamba/envs/surface/bin/teLeap: Warning!
#  Converting C-terminal residue name to PDB format: CSER -> SER
#
# /Users/ChristopherRivera/micromamba/envs/surface/bin/teLeap: Warning!
#  Converting N-terminal residue name to PDB format: NSER -> SER
#
# /Users/ChristopherRivera/micromamba/envs/surface/bin/teLeap: Warning!
#  Converting C-terminal residue name to PDB format: CLYS -> LYS
#
# /Users/ChristopherRivera/micromamba/envs/surface/bin/teLeap: Warning!
#  Converting N-terminal residue name to PDB format: NGLY -> GLY
#
# /Users/ChristopherRivera/micromamba/envs/surface/bin/teLeap: Warning!
#  Converting C-terminal residue name to PDB format: CGLU -> GLU
#
# /Users/ChristopherRivera/micromamba/envs/surface/bin/teLeap: Warning!
#  Converting N-terminal residue name to PDB format: NPRO -> PRO
#
# /Users/ChristopherRivera/micromamba/envs/surface/bin/teLeap: Warning!
#  Converting C-terminal residue name to PDB format: CSER -> SER
#
# /Users/ChristopherRivera/micromamba/envs/surface/bin/teLeap: Warning!
#  Converting N-terminal residue name to PDB format: NGLN -> GLN
#
# /Users/ChristopherRivera/micromamba/envs/surface/bin/teLeap: Warning!
#  Converting C-terminal residue name to PDB format: CSER -> SER
#
# /Users/ChristopherRivera/micromamba/envs/surface/bin/teLeap: Warning!
#  Converting N-terminal residue name to PDB format: NVAL -> VAL
#
# /Users/ChristopherRivera/micromamba/envs/surface/bin/teLeap: Warning!
#  Converting C-terminal residue name to PDB format: CGLY -> GLY
#
# /Users/ChristopherRivera/micromamba/envs/surface/bin/teLeap: Warning!
#  Converting N-terminal residue name to PDB format: NALA -> ALA
#
# /Users/ChristopherRivera/micromamba/envs/surface/bin/teLeap: Warning!
#  Converting C-terminal residue name to PDB format: CASN -> ASN
#
# /Users/ChristopherRivera/micromamba/envs/surface/bin/teLeap: Warning!
#  Converting N-terminal residue name to PDB format: NTHR -> THR
#
# /Users/ChristopherRivera/micromamba/envs/surface/bin/teLeap: Warning!
#  Converting C-terminal residue name to PDB format: CPRO -> PRO
#
# /Users/ChristopherRivera/micromamba/envs/surface/bin/teLeap: Warning!
#  Converting N-terminal residue name to PDB format: NASP -> ASP
#
# /Users/ChristopherRivera/micromamba/envs/surface/bin/teLeap: Warning!
#  Converting C-terminal residue name to PDB format: CASN -> ASN
#
# /Users/ChristopherRivera/micromamba/envs/surface/bin/teLeap: Warning!
#  Converting N-terminal residue name to PDB format: NGLU -> GLU
#
# /Users/ChristopherRivera/micromamba/envs/surface/bin/teLeap: Warning!
#  Converting C-terminal residue name to PDB format: CARG -> ARG
#
# /Users/ChristopherRivera/micromamba/envs/surface/bin/teLeap: Warning!
#  Converting N-terminal residue name to PDB format: NLEU -> LEU
#
# /Users/ChristopherRivera/micromamba/envs/surface/bin/teLeap: Warning!
#  Converting C-terminal residue name to PDB format: CLEU -> LEU
# Checking Unit.
#
# /Users/ChristopherRivera/micromamba/envs/surface/bin/teLeap: Warning!
# The unperturbed charge of the unit (3.000000) is not zero.
#
# /Users/ChristopherRivera/micromamba/envs/surface/bin/teLeap: Note.
# Ignoring the warning from Unit Checking.
#
# Building topology.
# Building atom parameters.
# Building bond parameters.
# Building angle parameters.
# Building proper torsion parameters.
# Building improper torsion parameters.
#  total 701 improper torsions applied
# Building H-Bond parameters.
# Incorporating Non-Bonded adjustments.
# Not Marking per-residue atom chain types.
# Marking per-residue atom chain types.
#   (Residues lacking connect0/connect1 -
#    these don't have chain types marked:
#
# 	res	total affected
#
# 	CARG	1
# 	CASN	2
# 	CGLU	1
# 	CGLY	2
# 	CILE	1
# 	CLEU	1
# 	CLYS	1
# 	CPRO	1
# 	CSER	3
# 	NALA	1
# 	NASP	1
# 	NGLN	2
# 	NGLU	1
# 	NGLY	2
# 	NLEU	1
# 	NPRO	1
# 	NSER	2
# 	NTHR	1
# 	NVAL	1
#   )
#  (no restraints)
# 	Quit
#
# Exiting LEaP: Errors = 0; Warnings = 27; Notes = 1.
#
# 2023-11-03 20:43:29,348 [MainThread  ] [INFO ]  Removed: ['/Users/ChristopherRivera/Projects/developability/Notebooks/ab8da1d0-838e-482c-9548-90d284b33fe9', '45630182-1824-45d7-b4bc-cf1f261ccdad', 'leap.log']
# Finished Leap.
#
# Starting Sander with /Users/ChristopherRivera/Documents/DataResults/MPK190/predicted_pdbs/MPK190_VL_S69E_A76S_outputs/leap.pdb.
#
# 2023-11-03 20:43:29,350 [MainThread  ] [INFO ]  Executing biobb_amber.sander.sander_mdrun Version: 4.1.0
# 2023-11-03 20:43:29,352 [MainThread  ] [INFO ]  Copy: /Users/ChristopherRivera/Documents/DataResults/MPK190/predicted_pdbs/MPK190_VL_S69E_A76S_outputs/leap.top to /Users/ChristopherRivera/Projects/developability/Notebooks/5954e4e4-0423-4afa-a3a3-3e5d8fbac96f
# 2023-11-03 20:43:29,352 [MainThread  ] [INFO ]  Copy: /Users/ChristopherRivera/Documents/DataResults/MPK190/predicted_pdbs/MPK190_VL_S69E_A76S_outputs/leap.crd to /Users/ChristopherRivera/Projects/developability/Notebooks/5954e4e4-0423-4afa-a3a3-3e5d8fbac96f
# 2023-11-03 20:43:29,353 [MainThread  ] [INFO ]  Copy: /Users/ChristopherRivera/Documents/DataResults/MPK190/predicted_pdbs/MPK190_VL_S69E_A76S_outputs/leap.crd to /Users/ChristopherRivera/Projects/developability/Notebooks/5954e4e4-0423-4afa-a3a3-3e5d8fbac96f
# 2023-11-03 20:43:29,353 [MainThread  ] [INFO ]  Creating a2f2aae3-c4dc-4bd9-a26c-98cfbce3088b temporary folder
# 2023-11-03 20:43:29,354 [MainThread  ] [INFO ]  sander -O -i a2f2aae3-c4dc-4bd9-a26c-98cfbce3088b/sander.mdin -p /Users/ChristopherRivera/Projects/developability/Notebooks/5954e4e4-0423-4afa-a3a3-3e5d8fbac96f/leap.top -c /Users/ChristopherRivera/Projects/developability/Notebooks/5954e4e4-0423-4afa-a3a3-3e5d8fbac96f/leap.crd -r /Users/ChristopherRivera/Projects/developability/Notebooks/5954e4e4-0423-4afa-a3a3-3e5d8fbac96f/sander.rst -o /Users/ChristopherRivera/Projects/developability/Notebooks/5954e4e4-0423-4afa-a3a3-3e5d8fbac96f/sander.log -x /Users/ChristopherRivera/Projects/developability/Notebooks/5954e4e4-0423-4afa-a3a3-3e5d8fbac96f/sander.x -ref /Users/ChristopherRivera/Projects/developability/Notebooks/5954e4e4-0423-4afa-a3a3-3e5d8fbac96f/leap.crd
#
# 2023-11-03 20:43:34,083 [MainThread  ] [INFO ]  Exit code 0
#
# 2023-11-03 20:43:34,086 [MainThread  ] [INFO ]  Removed: ['/Users/ChristopherRivera/Projects/developability/Notebooks/5954e4e4-0423-4afa-a3a3-3e5d8fbac96f', 'mdinfo', 'a2f2aae3-c4dc-4bd9-a26c-98cfbce3088b']
# 2023-11-03 20:43:34,086 [MainThread  ] [INFO ]  Path /Users/ChristopherRivera/Documents/DataResults/MPK190/predicted_pdbs/MPK190_VL_S69E_A76S_outputs/sander.x --- biobb_amber.sander.sander_mdrun: Unexisting output_traj_path file.
# Finished Sander.
#
# Converting Sander results to pdb.
#
# 2023-11-03 20:43:34,088 [MainThread  ] [INFO ]  Executing biobb_amber.ambpdb.amber_to_pdb Version: 4.1.0
# 2023-11-03 20:43:34,089 [MainThread  ] [INFO ]  Copy: /Users/ChristopherRivera/Documents/DataResults/MPK190/predicted_pdbs/MPK190_VL_S69E_A76S_outputs/leap.top to /Users/ChristopherRivera/Projects/developability/Notebooks/1f86f22b-7a29-4177-8683-26974e8f62f1
# 2023-11-03 20:43:34,090 [MainThread  ] [INFO ]  Copy: /Users/ChristopherRivera/Documents/DataResults/MPK190/predicted_pdbs/MPK190_VL_S69E_A76S_outputs/sander.rst to /Users/ChristopherRivera/Projects/developability/Notebooks/1f86f22b-7a29-4177-8683-26974e8f62f1
# 2023-11-03 20:43:34,090 [MainThread  ] [INFO ]  ambpdb -p /Users/ChristopherRivera/Projects/developability/Notebooks/1f86f22b-7a29-4177-8683-26974e8f62f1/leap.top -c /Users/ChristopherRivera/Projects/developability/Notebooks/1f86f22b-7a29-4177-8683-26974e8f62f1/sander.rst >  /Users/ChristopherRivera/Projects/developability/Notebooks/1f86f22b-7a29-4177-8683-26974e8f62f1/MPK190_VL_S69E_A76S.energy_minimized.pdb
#
# 2023-11-03 20:43:34,145 [MainThread  ] [INFO ]  Exit code 0
#
# 2023-11-03 20:43:34,147 [MainThread  ] [INFO ]  Removed: ['/Users/ChristopherRivera/Projects/developability/Notebooks/1f86f22b-7a29-4177-8683-26974e8f62f1']
# Finished conversion
#
# Starting pdb2pqr on MPK190_VL_S69E_A76S.energy_minimized.pdb
#
# Generating APBS ini file.
#
# Running APBS.
#
#  Writing data to flat file /Users/ChristopherRivera/Documents/DataResults/MPK190/predicted_pdbs/MPK190_VL_S69E_A76S_outputs/MPK190_VL_S69E_A76S.energy_minimized.pqr.log...
#
#
# Starting Nanoshaper on MPK190_VL_S69E_A76S.energy_minimized.xyzr file.
#
# Finished Nanoshaper, now creating coordinates.csv.
#
# Finished extracting xyz and atoms.
#
# Now extracting pertinent potential values using multivalue.
#
# /Users/ChristopherRivera/bioprograms/APBS-3.4.1.Darwin/share/apbs/tools/bin/multivalue /Users/ChristopherRivera/Documents/DataResults/MPK190/predicted_pdbs/MPK190_VL_S69E_A76S_outputs/triangulatedSurf.csv /Users/ChristopherRivera/Documents/DataResults/MPK190/predicted_pdbs/MPK190_VL_S69E_A76S_outputs/MPK190_VL_S69E_A76S.energy_minimized.pqr.dx /Users/ChristopherRivera/Documents/DataResults/MPK190/predicted_pdbs/MPK190_VL_S69E_A76S_outputs/potential_coordinates.csv
# Finished extracting potential values.
# Now mapping potential to individual atoms in  pqr_file.
#
# Finished mapping potentials to atoms.
# Now aggregating potentials over residues.
#
# Finished...
# Starting pdb4amber with /Users/ChristopherRivera/Documents/DataResults/MPK190/predicted_pdbs/MPK190_VH_V2D_Q3E_K13Q_VL_R17E_A76S.pdb.
#
# 2023-11-03 20:43:42,358 [MainThread  ] [INFO ]  Executing biobb_amber.pdb4amber.pdb4amber_run Version: 4.1.0
# 2023-11-03 20:43:42,359 [MainThread  ] [INFO ]  Copy: /Users/ChristopherRivera/Documents/DataResults/MPK190/predicted_pdbs/MPK190_VH_V2D_Q3E_K13Q_VL_R17E_A76S.pdb to /Users/ChristopherRivera/Projects/developability/Notebooks/648bff35-3643-429c-80bb-3a6676829ece
# 2023-11-03 20:43:42,360 [MainThread  ] [INFO ]  Creating 22a2d0ac-6da3-4715-85cc-db1d195e7751 temporary folder
# 2023-11-03 20:43:42,360 [MainThread  ] [INFO ]  pdb4amber -i /Users/ChristopherRivera/Projects/developability/Notebooks/648bff35-3643-429c-80bb-3a6676829ece/MPK190_VH_V2D_Q3E_K13Q_VL_R17E_A76S.pdb -o /Users/ChristopherRivera/Projects/developability/Notebooks/648bff35-3643-429c-80bb-3a6676829ece/pdb4amber.pdb -y
#
# 2023-11-03 20:43:42,839 [MainThread  ] [INFO ]  Exit code 0
#
# 2023-11-03 20:43:42,840 [MainThread  ] [INFO ]
# ==================================================
# Summary of pdb4amber for: /Users/ChristopherRivera/Projects/developability/Notebooks/648bff35-3643-429c-80bb-3a6676829ece/MPK190_VH_V2D_Q3E_K13Q_VL_R17E_A76S.pdb
# ===================================================
#
# ----------Chains
# The following (original) chains have been found:
# H
# L
#
# ---------- Alternate Locations (Original Residues!))
#
# The following residues had alternate locations:
# None
# -----------Non-standard-resnames
#
#
# ---------- Missing heavy atom(s)
#
# None
#
# 2023-11-03 20:43:42,842 [MainThread  ] [INFO ]  Removed: ['/Users/ChristopherRivera/Projects/developability/Notebooks/648bff35-3643-429c-80bb-3a6676829ece', '22a2d0ac-6da3-4715-85cc-db1d195e7751']
# Finished pdb4amber.
#
# Starting Leap with /Users/ChristopherRivera/Documents/DataResults/MPK190/predicted_pdbs/MPK190_VH_V2D_Q3E_K13Q_VL_R17E_A76S_outputs/pdb4amber.pdb.
#
# 2023-11-03 20:43:42,844 [MainThread  ] [INFO ]  Executing biobb_amber.leap.leap_gen_top Version: 4.1.0
# 2023-11-03 20:43:42,845 [MainThread  ] [INFO ]  Copy: /Users/ChristopherRivera/Documents/DataResults/MPK190/predicted_pdbs/MPK190_VH_V2D_Q3E_K13Q_VL_R17E_A76S_outputs/pdb4amber.pdb to /Users/ChristopherRivera/Projects/developability/Notebooks/33950f15-3c05-4b20-95c9-16cd99343531
# 2023-11-03 20:43:42,845 [MainThread  ] [INFO ]  Creating c3ab4dfe-93e1-4a9c-a1c8-f91e12473ddc temporary folder
# 2023-11-03 20:43:42,846 [MainThread  ] [INFO ]  tleap -f c3ab4dfe-93e1-4a9c-a1c8-f91e12473ddc/leap.in
#
# 2023-11-03 20:43:43,121 [MainThread  ] [INFO ]  Exit code 0
#
# 2023-11-03 20:43:43,122 [MainThread  ] [INFO ]  -I: Adding /Users/ChristopherRivera/micromamba/envs/surface/dat/leap/prep to search path.
# -I: Adding /Users/ChristopherRivera/micromamba/envs/surface/dat/leap/lib to search path.
# -I: Adding /Users/ChristopherRivera/micromamba/envs/surface/dat/leap/parm to search path.
# -I: Adding /Users/ChristopherRivera/micromamba/envs/surface/dat/leap/cmd to search path.
# -f: Source c3ab4dfe-93e1-4a9c-a1c8-f91e12473ddc/leap.in.
#
# Welcome to LEaP!
# (no leaprc in search path)
# Sourcing: ./c3ab4dfe-93e1-4a9c-a1c8-f91e12473ddc/leap.in
# ----- Source: /Users/ChristopherRivera/micromamba/envs/surface/dat/leap/cmd/leaprc.protein.ff19SB
# ----- Source of /Users/ChristopherRivera/micromamba/envs/surface/dat/leap/cmd/leaprc.protein.ff19SB done
# Log file: ./leap.log
# Loading parameters: /Users/ChristopherRivera/micromamba/envs/surface/dat/leap/parm/parm19.dat
# Reading title:
# PARM99 + frcmod.ff99SB + frcmod.parmbsc0 + OL3 for RNA + ff19SB
# Loading parameters: /Users/ChristopherRivera/micromamba/envs/surface/dat/leap/parm/frcmod.ff19SB
# Reading force field modification type file (frcmod)
# Reading title:
# ff19SB AA-specific backbone CMAPs for protein 07/25/2019
# Loading library: /Users/ChristopherRivera/micromamba/envs/surface/dat/leap/lib/amino19.lib
# Loading library: /Users/ChristopherRivera/micromamba/envs/surface/dat/leap/lib/aminoct12.lib
# Loading library: /Users/ChristopherRivera/micromamba/envs/surface/dat/leap/lib/aminont12.lib
# Loading library: /Users/ChristopherRivera/micromamba/envs/surface/dat/leap/lib/atomic_ions.lib
# Loading PDB file: /Users/ChristopherRivera/Projects/developability/Notebooks/33950f15-3c05-4b20-95c9-16cd99343531/pdb4amber.pdb
#   Added missing heavy atom: .R<CGLY 9>.A<OXT 8>
#   Added missing heavy atom: .R<CILE 29>.A<OXT 20>
#   Added missing heavy atom: .R<CSER 54>.A<OXT 12>
#   Added missing heavy atom: .R<CLYS 65>.A<OXT 23>
#   Added missing heavy atom: .R<CGLU 102>.A<OXT 16>
#   Added missing heavy atom: .R<CSER 128>.A<OXT 12>
#   Added missing heavy atom: .R<CGLY 149>.A<OXT 8>
#   Added missing heavy atom: .R<CASN 172>.A<OXT 15>
#   Added missing heavy atom: .R<CPRO 180>.A<OXT 15>
#   Added missing heavy atom: .R<CASN 187>.A<OXT 15>
#   Added missing heavy atom: .R<CARG 215>.A<OXT 25>
#   total atoms in file: 1719
#   Leap added 1689 missing atoms according to residue templates:
#        11 Heavy
#        1678 H / lone pairs
# Writing pdb file: /Users/ChristopherRivera/Projects/developability/Notebooks/33950f15-3c05-4b20-95c9-16cd99343531/leap.pdb
#
# /Users/ChristopherRivera/micromamba/envs/surface/bin/teLeap: Warning!
#  Converting N-terminal residue name to PDB format: NGLN -> GLN
#
# /Users/ChristopherRivera/micromamba/envs/surface/bin/teLeap: Warning!
#  Converting C-terminal residue name to PDB format: CGLY -> GLY
#
# /Users/ChristopherRivera/micromamba/envs/surface/bin/teLeap: Warning!
#  Converting N-terminal residue name to PDB format: NGLY -> GLY
#
# /Users/ChristopherRivera/micromamba/envs/surface/bin/teLeap: Warning!
#  Converting C-terminal residue name to PDB format: CILE -> ILE
#
# /Users/ChristopherRivera/micromamba/envs/surface/bin/teLeap: Warning!
#  Converting N-terminal residue name to PDB format: NSER -> SER
#
# /Users/ChristopherRivera/micromamba/envs/surface/bin/teLeap: Warning!
#  Converting C-terminal residue name to PDB format: CSER -> SER
#
# /Users/ChristopherRivera/micromamba/envs/surface/bin/teLeap: Warning!
#  Converting N-terminal residue name to PDB format: NSER -> SER
#
# /Users/ChristopherRivera/micromamba/envs/surface/bin/teLeap: Warning!
#  Converting C-terminal residue name to PDB format: CLYS -> LYS
#
# /Users/ChristopherRivera/micromamba/envs/surface/bin/teLeap: Warning!
#  Converting N-terminal residue name to PDB format: NGLY -> GLY
#
# /Users/ChristopherRivera/micromamba/envs/surface/bin/teLeap: Warning!
#  Converting C-terminal residue name to PDB format: CGLU -> GLU
#
# /Users/ChristopherRivera/micromamba/envs/surface/bin/teLeap: Warning!
#  Converting N-terminal residue name to PDB format: NPRO -> PRO
#
# /Users/ChristopherRivera/micromamba/envs/surface/bin/teLeap: Warning!
#  Converting C-terminal residue name to PDB format: CSER -> SER
#
# /Users/ChristopherRivera/micromamba/envs/surface/bin/teLeap: Warning!
#  Converting N-terminal residue name to PDB format: NGLN -> GLN
#
# /Users/ChristopherRivera/micromamba/envs/surface/bin/teLeap: Warning!
#  Converting C-terminal residue name to PDB format: CSER -> SER
#
# /Users/ChristopherRivera/micromamba/envs/surface/bin/teLeap: Warning!
#  Converting N-terminal residue name to PDB format: NVAL -> VAL
#
# /Users/ChristopherRivera/micromamba/envs/surface/bin/teLeap: Warning!
#  Converting C-terminal residue name to PDB format: CGLY -> GLY
#
# /Users/ChristopherRivera/micromamba/envs/surface/bin/teLeap: Warning!
#  Converting N-terminal residue name to PDB format: NALA -> ALA
#
# /Users/ChristopherRivera/micromamba/envs/surface/bin/teLeap: Warning!
#  Converting C-terminal residue name to PDB format: CASN -> ASN
#
# /Users/ChristopherRivera/micromamba/envs/surface/bin/teLeap: Warning!
#  Converting N-terminal residue name to PDB format: NTHR -> THR
#
# /Users/ChristopherRivera/micromamba/envs/surface/bin/teLeap: Warning!
#  Converting C-terminal residue name to PDB format: CPRO -> PRO
#
# /Users/ChristopherRivera/micromamba/envs/surface/bin/teLeap: Warning!
#  Converting N-terminal residue name to PDB format: NASP -> ASP
#
# /Users/ChristopherRivera/micromamba/envs/surface/bin/teLeap: Warning!
#  Converting C-terminal residue name to PDB format: CASN -> ASN
#
# /Users/ChristopherRivera/micromamba/envs/surface/bin/teLeap: Warning!
#  Converting N-terminal residue name to PDB format: NSER -> SER
#
# /Users/ChristopherRivera/micromamba/envs/surface/bin/teLeap: Warning!
#  Converting C-terminal residue name to PDB format: CARG -> ARG
#
# /Users/ChristopherRivera/micromamba/envs/surface/bin/teLeap: Warning!
#  Converting N-terminal residue name to PDB format: NLEU -> LEU
#
# /Users/ChristopherRivera/micromamba/envs/surface/bin/teLeap: Warning!
#  Converting C-terminal residue name to PDB format: CLEU -> LEU
# Checking Unit.
#
# /Users/ChristopherRivera/micromamba/envs/surface/bin/teLeap: Warning!
# The unperturbed charge of the unit (-1.000000) is not zero.
#
# /Users/ChristopherRivera/micromamba/envs/surface/bin/teLeap: Note.
# Ignoring the warning from Unit Checking.
#
# Building topology.
# Building atom parameters.
# Building bond parameters.
# Building angle parameters.
# Building proper torsion parameters.
# Building improper torsion parameters.
#  total 699 improper torsions applied
# Building H-Bond parameters.
# Incorporating Non-Bonded adjustments.
# Not Marking per-residue atom chain types.
# Marking per-residue atom chain types.
#   (Residues lacking connect0/connect1 -
#    these don't have chain types marked:
#
# 	res	total affected
#
# 	CARG	1
# 	CASN	2
# 	CGLU	1
# 	CGLY	2
# 	CILE	1
# 	CLEU	1
# 	CLYS	1
# 	CPRO	1
# 	CSER	3
# 	NALA	1
# 	NASP	1
# 	NGLN	2
# 	NGLY	2
# 	NLEU	1
# 	NPRO	1
# 	NSER	3
# 	NTHR	1
# 	NVAL	1
#   )
#  (no restraints)
# 	Quit
#
# Exiting LEaP: Errors = 0; Warnings = 27; Notes = 1.
#
# 2023-11-03 20:43:43,125 [MainThread  ] [INFO ]  Removed: ['/Users/ChristopherRivera/Projects/developability/Notebooks/33950f15-3c05-4b20-95c9-16cd99343531', 'c3ab4dfe-93e1-4a9c-a1c8-f91e12473ddc', 'leap.log']
# Finished Leap.
#
# Starting Sander with /Users/ChristopherRivera/Documents/DataResults/MPK190/predicted_pdbs/MPK190_VH_V2D_Q3E_K13Q_VL_R17E_A76S_outputs/leap.pdb.
#
# 2023-11-03 20:43:43,127 [MainThread  ] [INFO ]  Executing biobb_amber.sander.sander_mdrun Version: 4.1.0
# 2023-11-03 20:43:43,129 [MainThread  ] [INFO ]  Copy: /Users/ChristopherRivera/Documents/DataResults/MPK190/predicted_pdbs/MPK190_VH_V2D_Q3E_K13Q_VL_R17E_A76S_outputs/leap.top to /Users/ChristopherRivera/Projects/developability/Notebooks/6ce3115b-b185-4379-8cca-afeb79e30b42
# 2023-11-03 20:43:43,129 [MainThread  ] [INFO ]  Copy: /Users/ChristopherRivera/Documents/DataResults/MPK190/predicted_pdbs/MPK190_VH_V2D_Q3E_K13Q_VL_R17E_A76S_outputs/leap.crd to /Users/ChristopherRivera/Projects/developability/Notebooks/6ce3115b-b185-4379-8cca-afeb79e30b42
# 2023-11-03 20:43:43,130 [MainThread  ] [INFO ]  Copy: /Users/ChristopherRivera/Documents/DataResults/MPK190/predicted_pdbs/MPK190_VH_V2D_Q3E_K13Q_VL_R17E_A76S_outputs/leap.crd to /Users/ChristopherRivera/Projects/developability/Notebooks/6ce3115b-b185-4379-8cca-afeb79e30b42
# 2023-11-03 20:43:43,130 [MainThread  ] [INFO ]  Creating 5b92d15e-b27e-4fb0-9dc5-ae15f98a1e20 temporary folder
# 2023-11-03 20:43:43,131 [MainThread  ] [INFO ]  sander -O -i 5b92d15e-b27e-4fb0-9dc5-ae15f98a1e20/sander.mdin -p /Users/ChristopherRivera/Projects/developability/Notebooks/6ce3115b-b185-4379-8cca-afeb79e30b42/leap.top -c /Users/ChristopherRivera/Projects/developability/Notebooks/6ce3115b-b185-4379-8cca-afeb79e30b42/leap.crd -r /Users/ChristopherRivera/Projects/developability/Notebooks/6ce3115b-b185-4379-8cca-afeb79e30b42/sander.rst -o /Users/ChristopherRivera/Projects/developability/Notebooks/6ce3115b-b185-4379-8cca-afeb79e30b42/sander.log -x /Users/ChristopherRivera/Projects/developability/Notebooks/6ce3115b-b185-4379-8cca-afeb79e30b42/sander.x -ref /Users/ChristopherRivera/Projects/developability/Notebooks/6ce3115b-b185-4379-8cca-afeb79e30b42/leap.crd
#
# 2023-11-03 20:43:47,825 [MainThread  ] [INFO ]  Exit code 0
#
# 2023-11-03 20:43:47,828 [MainThread  ] [INFO ]  Removed: ['/Users/ChristopherRivera/Projects/developability/Notebooks/6ce3115b-b185-4379-8cca-afeb79e30b42', 'mdinfo', '5b92d15e-b27e-4fb0-9dc5-ae15f98a1e20']
# 2023-11-03 20:43:47,829 [MainThread  ] [INFO ]  Path /Users/ChristopherRivera/Documents/DataResults/MPK190/predicted_pdbs/MPK190_VH_V2D_Q3E_K13Q_VL_R17E_A76S_outputs/sander.x --- biobb_amber.sander.sander_mdrun: Unexisting output_traj_path file.
# Finished Sander.
#
# Converting Sander results to pdb.
#
# 2023-11-03 20:43:47,830 [MainThread  ] [INFO ]  Executing biobb_amber.ambpdb.amber_to_pdb Version: 4.1.0
# 2023-11-03 20:43:47,831 [MainThread  ] [INFO ]  Copy: /Users/ChristopherRivera/Documents/DataResults/MPK190/predicted_pdbs/MPK190_VH_V2D_Q3E_K13Q_VL_R17E_A76S_outputs/leap.top to /Users/ChristopherRivera/Projects/developability/Notebooks/d700e44c-7df2-4288-9251-11249c57aac6
# 2023-11-03 20:43:47,832 [MainThread  ] [INFO ]  Copy: /Users/ChristopherRivera/Documents/DataResults/MPK190/predicted_pdbs/MPK190_VH_V2D_Q3E_K13Q_VL_R17E_A76S_outputs/sander.rst to /Users/ChristopherRivera/Projects/developability/Notebooks/d700e44c-7df2-4288-9251-11249c57aac6
# 2023-11-03 20:43:47,832 [MainThread  ] [INFO ]  ambpdb -p /Users/ChristopherRivera/Projects/developability/Notebooks/d700e44c-7df2-4288-9251-11249c57aac6/leap.top -c /Users/ChristopherRivera/Projects/developability/Notebooks/d700e44c-7df2-4288-9251-11249c57aac6/sander.rst >  /Users/ChristopherRivera/Projects/developability/Notebooks/d700e44c-7df2-4288-9251-11249c57aac6/MPK190_VH_V2D_Q3E_K13Q_VL_R17E_A76S.energy_minimized.pdb
#
# 2023-11-03 20:43:47,887 [MainThread  ] [INFO ]  Exit code 0
#
# 2023-11-03 20:43:47,889 [MainThread  ] [INFO ]  Removed: ['/Users/ChristopherRivera/Projects/developability/Notebooks/d700e44c-7df2-4288-9251-11249c57aac6']
# Finished conversion
#
# Starting pdb2pqr on MPK190_VH_V2D_Q3E_K13Q_VL_R17E_A76S.energy_minimized.pdb
#
# Generating APBS ini file.
#
# Running APBS.
#
#  Writing data to flat file /Users/ChristopherRivera/Documents/DataResults/MPK190/predicted_pdbs/MPK190_VH_V2D_Q3E_K13Q_VL_R17E_A76S_outputs/MPK190_VH_V2D_Q3E_K13Q_VL_R17E_A76S.energy_minimized.pqr.log...
#
#
# Starting Nanoshaper on MPK190_VH_V2D_Q3E_K13Q_VL_R17E_A76S.energy_minimized.xyzr file.
#
# Finished Nanoshaper, now creating coordinates.csv.
#
# Finished extracting xyz and atoms.
#
# Now extracting pertinent potential values using multivalue.
#
# /Users/ChristopherRivera/bioprograms/APBS-3.4.1.Darwin/share/apbs/tools/bin/multivalue /Users/ChristopherRivera/Documents/DataResults/MPK190/predicted_pdbs/MPK190_VH_V2D_Q3E_K13Q_VL_R17E_A76S_outputs/triangulatedSurf.csv /Users/ChristopherRivera/Documents/DataResults/MPK190/predicted_pdbs/MPK190_VH_V2D_Q3E_K13Q_VL_R17E_A76S_outputs/MPK190_VH_V2D_Q3E_K13Q_VL_R17E_A76S.energy_minimized.pqr.dx /Users/ChristopherRivera/Documents/DataResults/MPK190/predicted_pdbs/MPK190_VH_V2D_Q3E_K13Q_VL_R17E_A76S_outputs/potential_coordinates.csv
# Finished extracting potential values.
# Now mapping potential to individual atoms in  pqr_file.
#
# Finished mapping potentials to atoms.
# Now aggregating potentials over residues.
#
# Finished...
# Starting pdb4amber with /Users/ChristopherRivera/Documents/DataResults/MPK190/predicted_pdbs/MPK190_VH_V5E_VL_S69E_A76S.pdb.
#
# 2023-11-03 20:43:55,881 [MainThread  ] [INFO ]  Executing biobb_amber.pdb4amber.pdb4amber_run Version: 4.1.0
# 2023-11-03 20:43:55,883 [MainThread  ] [INFO ]  Copy: /Users/ChristopherRivera/Documents/DataResults/MPK190/predicted_pdbs/MPK190_VH_V5E_VL_S69E_A76S.pdb to /Users/ChristopherRivera/Projects/developability/Notebooks/2ab3412d-f814-4a40-a6cd-284cf73b671e
# 2023-11-03 20:43:55,884 [MainThread  ] [INFO ]  Creating 256c827d-809c-4f52-b5ca-baf957e49e21 temporary folder
# 2023-11-03 20:43:55,884 [MainThread  ] [INFO ]  pdb4amber -i /Users/ChristopherRivera/Projects/developability/Notebooks/2ab3412d-f814-4a40-a6cd-284cf73b671e/MPK190_VH_V5E_VL_S69E_A76S.pdb -o /Users/ChristopherRivera/Projects/developability/Notebooks/2ab3412d-f814-4a40-a6cd-284cf73b671e/pdb4amber.pdb -y
#
# 2023-11-03 20:43:56,366 [MainThread  ] [INFO ]  Exit code 0
#
# 2023-11-03 20:43:56,367 [MainThread  ] [INFO ]
# ==================================================
# Summary of pdb4amber for: /Users/ChristopherRivera/Projects/developability/Notebooks/2ab3412d-f814-4a40-a6cd-284cf73b671e/MPK190_VH_V5E_VL_S69E_A76S.pdb
# ===================================================
#
# ----------Chains
# The following (original) chains have been found:
# H
# L
#
# ---------- Alternate Locations (Original Residues!))
#
# The following residues had alternate locations:
# None
# -----------Non-standard-resnames
#
#
# ---------- Missing heavy atom(s)
#
# None
#
# 2023-11-03 20:43:56,369 [MainThread  ] [INFO ]  Removed: ['/Users/ChristopherRivera/Projects/developability/Notebooks/2ab3412d-f814-4a40-a6cd-284cf73b671e', '256c827d-809c-4f52-b5ca-baf957e49e21']
# Finished pdb4amber.
#
# Starting Leap with /Users/ChristopherRivera/Documents/DataResults/MPK190/predicted_pdbs/MPK190_VH_V5E_VL_S69E_A76S_outputs/pdb4amber.pdb.
#
# 2023-11-03 20:43:56,371 [MainThread  ] [INFO ]  Executing biobb_amber.leap.leap_gen_top Version: 4.1.0
# 2023-11-03 20:43:56,372 [MainThread  ] [INFO ]  Copy: /Users/ChristopherRivera/Documents/DataResults/MPK190/predicted_pdbs/MPK190_VH_V5E_VL_S69E_A76S_outputs/pdb4amber.pdb to /Users/ChristopherRivera/Projects/developability/Notebooks/cdfe55cd-d92a-4120-a378-40f1ab7c7ae5
# 2023-11-03 20:43:56,372 [MainThread  ] [INFO ]  Creating 6249076f-c96b-4846-92c3-2306a3ad44d3 temporary folder
# 2023-11-03 20:43:56,373 [MainThread  ] [INFO ]  tleap -f 6249076f-c96b-4846-92c3-2306a3ad44d3/leap.in
#
# 2023-11-03 20:43:56,657 [MainThread  ] [INFO ]  Exit code 0
#
# 2023-11-03 20:43:56,658 [MainThread  ] [INFO ]  -I: Adding /Users/ChristopherRivera/micromamba/envs/surface/dat/leap/prep to search path.
# -I: Adding /Users/ChristopherRivera/micromamba/envs/surface/dat/leap/lib to search path.
# -I: Adding /Users/ChristopherRivera/micromamba/envs/surface/dat/leap/parm to search path.
# -I: Adding /Users/ChristopherRivera/micromamba/envs/surface/dat/leap/cmd to search path.
# -f: Source 6249076f-c96b-4846-92c3-2306a3ad44d3/leap.in.
#
# Welcome to LEaP!
# (no leaprc in search path)
# Sourcing: ./6249076f-c96b-4846-92c3-2306a3ad44d3/leap.in
# ----- Source: /Users/ChristopherRivera/micromamba/envs/surface/dat/leap/cmd/leaprc.protein.ff19SB
# ----- Source of /Users/ChristopherRivera/micromamba/envs/surface/dat/leap/cmd/leaprc.protein.ff19SB done
# Log file: ./leap.log
# Loading parameters: /Users/ChristopherRivera/micromamba/envs/surface/dat/leap/parm/parm19.dat
# Reading title:
# PARM99 + frcmod.ff99SB + frcmod.parmbsc0 + OL3 for RNA + ff19SB
# Loading parameters: /Users/ChristopherRivera/micromamba/envs/surface/dat/leap/parm/frcmod.ff19SB
# Reading force field modification type file (frcmod)
# Reading title:
# ff19SB AA-specific backbone CMAPs for protein 07/25/2019
# Loading library: /Users/ChristopherRivera/micromamba/envs/surface/dat/leap/lib/amino19.lib
# Loading library: /Users/ChristopherRivera/micromamba/envs/surface/dat/leap/lib/aminoct12.lib
# Loading library: /Users/ChristopherRivera/micromamba/envs/surface/dat/leap/lib/aminont12.lib
# ...
#
# 2023-11-03 21:15:28,065 [MainThread  ] [INFO ]  Removed: ['/Users/ChristopherRivera/Projects/developability/Notebooks/3a556b11-1589-4b42-96f2-d7e4182c624c']
# Finished conversion
#
# Starting pdb2pqr on MPK190_VH_Q3E_K13Q_K76Q.energy_minimized.pdb
#
# Generating APBS ini file.
#
# Running APBS.
#
#  Writing data to flat file /Users/ChristopherRivera/Documents/DataResults/MPK190/predicted_pdbs/MPK190_VH_Q3E_K13Q_K76Q_outputs/MPK190_VH_Q3E_K13Q_K76Q.energy_minimized.pqr.log...
#
#
# Starting Nanoshaper on MPK190_VH_Q3E_K13Q_K76Q.energy_minimized.xyzr file.
#
# Finished Nanoshaper, now creating coordinates.csv.
#
# Finished extracting xyz and atoms.
#
# Now extracting pertinent potential values using multivalue.
#
# /Users/ChristopherRivera/bioprograms/APBS-3.4.1.Darwin/share/apbs/tools/bin/multivalue /Users/ChristopherRivera/Documents/DataResults/MPK190/predicted_pdbs/MPK190_VH_Q3E_K13Q_K76Q_outputs/triangulatedSurf.csv /Users/ChristopherRivera/Documents/DataResults/MPK190/predicted_pdbs/MPK190_VH_Q3E_K13Q_K76Q_outputs/MPK190_VH_Q3E_K13Q_K76Q.energy_minimized.pqr.dx /Users/ChristopherRivera/Documents/DataResults/MPK190/predicted_pdbs/MPK190_VH_Q3E_K13Q_K76Q_outputs/potential_coordinates.csv
# Finished extracting potential values.
# Now mapping potential to individual atoms in  pqr_file.
#
# Finished mapping potentials to atoms.
# Now aggregating potentials over residues.
#
# Finished...
# Starting pdb4amber with /Users/ChristopherRivera/Documents/DataResults/MPK190/predicted_pdbs/MPK190_VH_Q3E_V5E_K13Q.pdb.
#
# 2023-11-03 21:15:36,233 [MainThread  ] [INFO ]  Executing biobb_amber.pdb4amber.pdb4amber_run Version: 4.1.0
# 2023-11-03 21:15:36,234 [MainThread  ] [INFO ]  Copy: /Users/ChristopherRivera/Documents/DataResults/MPK190/predicted_pdbs/MPK190_VH_Q3E_V5E_K13Q.pdb to /Users/ChristopherRivera/Projects/developability/Notebooks/5ff95ee7-3f19-42cc-a1e7-cc634043616c
# 2023-11-03 21:15:36,234 [MainThread  ] [INFO ]  Creating f4b5e6e3-aeb1-49c6-b6ec-d8560f58ee59 temporary folder
# 2023-11-03 21:15:36,235 [MainThread  ] [INFO ]  pdb4amber -i /Users/ChristopherRivera/Projects/developability/Notebooks/5ff95ee7-3f19-42cc-a1e7-cc634043616c/MPK190_VH_Q3E_V5E_K13Q.pdb -o /Users/ChristopherRivera/Projects/developability/Notebooks/5ff95ee7-3f19-42cc-a1e7-cc634043616c/pdb4amber.pdb -y
#
# 2023-11-03 21:15:36,705 [MainThread  ] [INFO ]  Exit code 0
#
# 2023-11-03 21:15:36,705 [MainThread  ] [INFO ]
# ==================================================
# Summary of pdb4amber for: /Users/ChristopherRivera/Projects/developability/Notebooks/5ff95ee7-3f19-42cc-a1e7-cc634043616c/MPK190_VH_Q3E_V5E_K13Q.pdb
# ===================================================
#
# ----------Chains
# The following (original) chains have been found:
# H
# L
#
# ---------- Alternate Locations (Original Residues!))
#
# The following residues had alternate locations:
# None
# -----------Non-standard-resnames
#
#
# ---------- Missing heavy atom(s)
#
# None
#
# 2023-11-03 21:15:36,707 [MainThread  ] [INFO ]  Removed: ['/Users/ChristopherRivera/Projects/developability/Notebooks/5ff95ee7-3f19-42cc-a1e7-cc634043616c', 'f4b5e6e3-aeb1-49c6-b6ec-d8560f58ee59']
# Finished pdb4amber.
#
# Starting Leap with /Users/ChristopherRivera/Documents/DataResults/MPK190/predicted_pdbs/MPK190_VH_Q3E_V5E_K13Q_outputs/pdb4amber.pdb.
#
# 2023-11-03 21:15:36,709 [MainThread  ] [INFO ]  Executing biobb_amber.leap.leap_gen_top Version: 4.1.0
# 2023-11-03 21:15:36,710 [MainThread  ] [INFO ]  Copy: /Users/ChristopherRivera/Documents/DataResults/MPK190/predicted_pdbs/MPK190_VH_Q3E_V5E_K13Q_outputs/pdb4amber.pdb to /Users/ChristopherRivera/Projects/developability/Notebooks/960502bb-0fe4-4c36-88f8-2adfa5ae6727
# 2023-11-03 21:15:36,710 [MainThread  ] [INFO ]  Creating 2c9727f7-3d4c-4b9a-be47-98eec2528a3e temporary folder
# 2023-11-03 21:15:36,711 [MainThread  ] [INFO ]  tleap -f 2c9727f7-3d4c-4b9a-be47-98eec2528a3e/leap.in
#
# 2023-11-03 21:15:37,021 [MainThread  ] [INFO ]  Exit code 0
#
# 2023-11-03 21:15:37,022 [MainThread  ] [INFO ]  -I: Adding /Users/ChristopherRivera/micromamba/envs/surface/dat/leap/prep to search path.
# -I: Adding /Users/ChristopherRivera/micromamba/envs/surface/dat/leap/lib to search path.
# -I: Adding /Users/ChristopherRivera/micromamba/envs/surface/dat/leap/parm to search path.
# -I: Adding /Users/ChristopherRivera/micromamba/envs/surface/dat/leap/cmd to search path.
# -f: Source 2c9727f7-3d4c-4b9a-be47-98eec2528a3e/leap.in.
#
# Welcome to LEaP!
# (no leaprc in search path)
# Sourcing: ./2c9727f7-3d4c-4b9a-be47-98eec2528a3e/leap.in
# ----- Source: /Users/ChristopherRivera/micromamba/envs/surface/dat/leap/cmd/leaprc.protein.ff19SB
# ----- Source of /Users/ChristopherRivera/micromamba/envs/surface/dat/leap/cmd/leaprc.protein.ff19SB done
# Log file: ./leap.log
# Loading parameters: /Users/ChristopherRivera/micromamba/envs/surface/dat/leap/parm/parm19.dat
# Reading title:
# PARM99 + frcmod.ff99SB + frcmod.parmbsc0 + OL3 for RNA + ff19SB
# Loading parameters: /Users/ChristopherRivera/micromamba/envs/surface/dat/leap/parm/frcmod.ff19SB
# Reading force field modification type file (frcmod)
# Reading title:
# ff19SB AA-specific backbone CMAPs for protein 07/25/2019
# Loading library: /Users/ChristopherRivera/micromamba/envs/surface/dat/leap/lib/amino19.lib
# Loading library: /Users/ChristopherRivera/micromamba/envs/surface/dat/leap/lib/aminoct12.lib
# Loading library: /Users/ChristopherRivera/micromamba/envs/surface/dat/leap/lib/aminont12.lib
# Loading library: /Users/ChristopherRivera/micromamba/envs/surface/dat/leap/lib/atomic_ions.lib
# Loading PDB file: /Users/ChristopherRivera/Projects/developability/Notebooks/960502bb-0fe4-4c36-88f8-2adfa5ae6727/pdb4amber.pdb
#   Added missing heavy atom: .R<CGLY 9>.A<OXT 8>
#   Added missing heavy atom: .R<CILE 29>.A<OXT 20>
#   Added missing heavy atom: .R<CSER 54>.A<OXT 12>
#   Added missing heavy atom: .R<CLYS 65>.A<OXT 23>
#   Added missing heavy atom: .R<CGLU 102>.A<OXT 16>
#   Added missing heavy atom: .R<CSER 128>.A<OXT 12>
#   Added missing heavy atom: .R<CGLY 149>.A<OXT 8>
#   Added missing heavy atom: .R<CASN 172>.A<OXT 15>
#   Added missing heavy atom: .R<CPRO 180>.A<OXT 15>
#   Added missing heavy atom: .R<CASN 187>.A<OXT 15>
#   Added missing heavy atom: .R<CARG 215>.A<OXT 25>
#   total atoms in file: 1721
#   Leap added 1698 missing atoms according to residue templates:
#        11 Heavy
#        1687 H / lone pairs
# Writing pdb file: /Users/ChristopherRivera/Projects/developability/Notebooks/960502bb-0fe4-4c36-88f8-2adfa5ae6727/leap.pdb
#
# /Users/ChristopherRivera/micromamba/envs/surface/bin/teLeap: Warning!
#  Converting N-terminal residue name to PDB format: NGLN -> GLN
#
# /Users/ChristopherRivera/micromamba/envs/surface/bin/teLeap: Warning!
#  Converting C-terminal residue name to PDB format: CGLY -> GLY
#
# /Users/ChristopherRivera/micromamba/envs/surface/bin/teLeap: Warning!
#  Converting N-terminal residue name to PDB format: NGLY -> GLY
#
# /Users/ChristopherRivera/micromamba/envs/surface/bin/teLeap: Warning!
#  Converting C-terminal residue name to PDB format: CILE -> ILE
#
# /Users/ChristopherRivera/micromamba/envs/surface/bin/teLeap: Warning!
#  Converting N-terminal residue name to PDB format: NSER -> SER
#
# /Users/ChristopherRivera/micromamba/envs/surface/bin/teLeap: Warning!
#  Converting C-terminal residue name to PDB format: CSER -> SER
#
# /Users/ChristopherRivera/micromamba/envs/surface/bin/teLeap: Warning!
#  Converting N-terminal residue name to PDB format: NSER -> SER
#
# /Users/ChristopherRivera/micromamba/envs/surface/bin/teLeap: Warning!
#  Converting C-terminal residue name to PDB format: CLYS -> LYS
#
# /Users/ChristopherRivera/micromamba/envs/surface/bin/teLeap: Warning!
#  Converting N-terminal residue name to PDB format: NGLY -> GLY
#
# /Users/ChristopherRivera/micromamba/envs/surface/bin/teLeap: Warning!
#  Converting C-terminal residue name to PDB format: CGLU -> GLU
#
# /Users/ChristopherRivera/micromamba/envs/surface/bin/teLeap: Warning!
#  Converting N-terminal residue name to PDB format: NPRO -> PRO
#
# /Users/ChristopherRivera/micromamba/envs/surface/bin/teLeap: Warning!
#  Converting C-terminal residue name to PDB format: CSER -> SER
#
# /Users/ChristopherRivera/micromamba/envs/surface/bin/teLeap: Warning!
#  Converting N-terminal residue name to PDB format: NGLN -> GLN
#
# /Users/ChristopherRivera/micromamba/envs/surface/bin/teLeap: Warning!
#  Converting C-terminal residue name to PDB format: CSER -> SER
#
# /Users/ChristopherRivera/micromamba/envs/surface/bin/teLeap: Warning!
#  Converting N-terminal residue name to PDB format: NVAL -> VAL
#
# /Users/ChristopherRivera/micromamba/envs/surface/bin/teLeap: Warning!
#  Converting C-terminal residue name to PDB format: CGLY -> GLY
#
# /Users/ChristopherRivera/micromamba/envs/surface/bin/teLeap: Warning!
#  Converting N-terminal residue name to PDB format: NALA -> ALA
#
# /Users/ChristopherRivera/micromamba/envs/surface/bin/teLeap: Warning!
#  Converting C-terminal residue name to PDB format: CASN -> ASN
#
# /Users/ChristopherRivera/micromamba/envs/surface/bin/teLeap: Warning!
#  Converting N-terminal residue name to PDB format: NTHR -> THR
#
# /Users/ChristopherRivera/micromamba/envs/surface/bin/teLeap: Warning!
#  Converting C-terminal residue name to PDB format: CPRO -> PRO
#
# /Users/ChristopherRivera/micromamba/envs/surface/bin/teLeap: Warning!
#  Converting N-terminal residue name to PDB format: NASP -> ASP
#
# /Users/ChristopherRivera/micromamba/envs/surface/bin/teLeap: Warning!
#  Converting C-terminal residue name to PDB format: CASN -> ASN
#
# /Users/ChristopherRivera/micromamba/envs/surface/bin/teLeap: Warning!
#  Converting N-terminal residue name to PDB format: NSER -> SER
#
# /Users/ChristopherRivera/micromamba/envs/surface/bin/teLeap: Warning!
#  Converting C-terminal residue name to PDB format: CARG -> ARG
#
# /Users/ChristopherRivera/micromamba/envs/surface/bin/teLeap: Warning!
#  Converting N-terminal residue name to PDB format: NLEU -> LEU
#
# /Users/ChristopherRivera/micromamba/envs/surface/bin/teLeap: Warning!
#  Converting C-terminal residue name to PDB format: CLEU -> LEU
# Checking Unit.
#
# /Users/ChristopherRivera/micromamba/envs/surface/bin/teLeap: Warning!
# The unperturbed charge of the unit (1.000000) is not zero.
#
# /Users/ChristopherRivera/micromamba/envs/surface/bin/teLeap: Note.
# Ignoring the warning from Unit Checking.
#
# Building topology.
# Building atom parameters.
# Building bond parameters.
# Building angle parameters.
# Building proper torsion parameters.
# Building improper torsion parameters.
#  total 702 improper torsions applied
# Building H-Bond parameters.
# Incorporating Non-Bonded adjustments.
# Not Marking per-residue atom chain types.
# Marking per-residue atom chain types.
#   (Residues lacking connect0/connect1 -
#    these don't have chain types marked:
#
# 	res	total affected
#
# 	CARG	1
# 	CASN	2
# 	CGLU	1
# 	CGLY	2
# 	CILE	1
# 	CLEU	1
# 	CLYS	1
# 	CPRO	1
# 	CSER	3
# 	NALA	1
# 	NASP	1
# 	NGLN	2
# 	NGLY	2
# 	NLEU	1
# 	NPRO	1
# 	NSER	3
# 	NTHR	1
# 	NVAL	1
#   )
#  (no restraints)
# 	Quit
#
# Exiting LEaP: Errors = 0; Warnings = 27; Notes = 1.
#
# 2023-11-03 21:15:37,025 [MainThread  ] [INFO ]  Removed: ['/Users/ChristopherRivera/Projects/developability/Notebooks/960502bb-0fe4-4c36-88f8-2adfa5ae6727', '2c9727f7-3d4c-4b9a-be47-98eec2528a3e', 'leap.log']
# Finished Leap.
#
# Starting Sander with /Users/ChristopherRivera/Documents/DataResults/MPK190/predicted_pdbs/MPK190_VH_Q3E_V5E_K13Q_outputs/leap.pdb.
#
# 2023-11-03 21:15:37,027 [MainThread  ] [INFO ]  Executing biobb_amber.sander.sander_mdrun Version: 4.1.0
# 2023-11-03 21:15:37,028 [MainThread  ] [INFO ]  Copy: /Users/ChristopherRivera/Documents/DataResults/MPK190/predicted_pdbs/MPK190_VH_Q3E_V5E_K13Q_outputs/leap.top to /Users/ChristopherRivera/Projects/developability/Notebooks/dd3e7abf-ccc2-4e3c-ab29-16415c4718a3
# 2023-11-03 21:15:37,029 [MainThread  ] [INFO ]  Copy: /Users/ChristopherRivera/Documents/DataResults/MPK190/predicted_pdbs/MPK190_VH_Q3E_V5E_K13Q_outputs/leap.crd to /Users/ChristopherRivera/Projects/developability/Notebooks/dd3e7abf-ccc2-4e3c-ab29-16415c4718a3
# 2023-11-03 21:15:37,030 [MainThread  ] [INFO ]  Copy: /Users/ChristopherRivera/Documents/DataResults/MPK190/predicted_pdbs/MPK190_VH_Q3E_V5E_K13Q_outputs/leap.crd to /Users/ChristopherRivera/Projects/developability/Notebooks/dd3e7abf-ccc2-4e3c-ab29-16415c4718a3
# 2023-11-03 21:15:37,030 [MainThread  ] [INFO ]  Creating 6c51c58c-5f78-447d-9be9-c502c3f6bb91 temporary folder
# 2023-11-03 21:15:37,031 [MainThread  ] [INFO ]  sander -O -i 6c51c58c-5f78-447d-9be9-c502c3f6bb91/sander.mdin -p /Users/ChristopherRivera/Projects/developability/Notebooks/dd3e7abf-ccc2-4e3c-ab29-16415c4718a3/leap.top -c /Users/ChristopherRivera/Projects/developability/Notebooks/dd3e7abf-ccc2-4e3c-ab29-16415c4718a3/leap.crd -r /Users/ChristopherRivera/Projects/developability/Notebooks/dd3e7abf-ccc2-4e3c-ab29-16415c4718a3/sander.rst -o /Users/ChristopherRivera/Projects/developability/Notebooks/dd3e7abf-ccc2-4e3c-ab29-16415c4718a3/sander.log -x /Users/ChristopherRivera/Projects/developability/Notebooks/dd3e7abf-ccc2-4e3c-ab29-16415c4718a3/sander.x -ref /Users/ChristopherRivera/Projects/developability/Notebooks/dd3e7abf-ccc2-4e3c-ab29-16415c4718a3/leap.crd
#
# 2023-11-03 21:15:41,687 [MainThread  ] [INFO ]  Exit code 0
#
# 2023-11-03 21:15:41,690 [MainThread  ] [INFO ]  Removed: ['/Users/ChristopherRivera/Projects/developability/Notebooks/dd3e7abf-ccc2-4e3c-ab29-16415c4718a3', 'mdinfo', '6c51c58c-5f78-447d-9be9-c502c3f6bb91']
# 2023-11-03 21:15:41,690 [MainThread  ] [INFO ]  Path /Users/ChristopherRivera/Documents/DataResults/MPK190/predicted_pdbs/MPK190_VH_Q3E_V5E_K13Q_outputs/sander.x --- biobb_amber.sander.sander_mdrun: Unexisting output_traj_path file.
# Finished Sander.
#
# Converting Sander results to pdb.
#
# 2023-11-03 21:15:41,692 [MainThread  ] [INFO ]  Executing biobb_amber.ambpdb.amber_to_pdb Version: 4.1.0
# 2023-11-03 21:15:41,693 [MainThread  ] [INFO ]  Copy: /Users/ChristopherRivera/Documents/DataResults/MPK190/predicted_pdbs/MPK190_VH_Q3E_V5E_K13Q_outputs/leap.top to /Users/ChristopherRivera/Projects/developability/Notebooks/7ce9149d-47bc-402a-a999-abc42e4763bd
# 2023-11-03 21:15:41,694 [MainThread  ] [INFO ]  Copy: /Users/ChristopherRivera/Documents/DataResults/MPK190/predicted_pdbs/MPK190_VH_Q3E_V5E_K13Q_outputs/sander.rst to /Users/ChristopherRivera/Projects/developability/Notebooks/7ce9149d-47bc-402a-a999-abc42e4763bd
# 2023-11-03 21:15:41,695 [MainThread  ] [INFO ]  ambpdb -p /Users/ChristopherRivera/Projects/developability/Notebooks/7ce9149d-47bc-402a-a999-abc42e4763bd/leap.top -c /Users/ChristopherRivera/Projects/developability/Notebooks/7ce9149d-47bc-402a-a999-abc42e4763bd/sander.rst >  /Users/ChristopherRivera/Projects/developability/Notebooks/7ce9149d-47bc-402a-a999-abc42e4763bd/MPK190_VH_Q3E_V5E_K13Q.energy_minimized.pdb
#
# 2023-11-03 21:15:41,821 [MainThread  ] [INFO ]  Exit code 0
#
# 2023-11-03 21:15:41,823 [MainThread  ] [INFO ]  Removed: ['/Users/ChristopherRivera/Projects/developability/Notebooks/7ce9149d-47bc-402a-a999-abc42e4763bd']
# Finished conversion
#
# Starting pdb2pqr on MPK190_VH_Q3E_V5E_K13Q.energy_minimized.pdb
#
# Generating APBS ini file.
#
# Running APBS.
#
#  Writing data to flat file /Users/ChristopherRivera/Documents/DataResults/MPK190/predicted_pdbs/MPK190_VH_Q3E_V5E_K13Q_outputs/MPK190_VH_Q3E_V5E_K13Q.energy_minimized.pqr.log...
#
#
# Starting Nanoshaper on MPK190_VH_Q3E_V5E_K13Q.energy_minimized.xyzr file.
#
# Finished Nanoshaper, now creating coordinates.csv.
#
# Finished extracting xyz and atoms.
#
# Now extracting pertinent potential values using multivalue.
#
# /Users/ChristopherRivera/bioprograms/APBS-3.4.1.Darwin/share/apbs/tools/bin/multivalue /Users/ChristopherRivera/Documents/DataResults/MPK190/predicted_pdbs/MPK190_VH_Q3E_V5E_K13Q_outputs/triangulatedSurf.csv /Users/ChristopherRivera/Documents/DataResults/MPK190/predicted_pdbs/MPK190_VH_Q3E_V5E_K13Q_outputs/MPK190_VH_Q3E_V5E_K13Q.energy_minimized.pqr.dx /Users/ChristopherRivera/Documents/DataResults/MPK190/predicted_pdbs/MPK190_VH_Q3E_V5E_K13Q_outputs/potential_coordinates.csv
# Finished extracting potential values.
# Now mapping potential to individual atoms in  pqr_file.
#
# Finished mapping potentials to atoms.
# Now aggregating potentials over residues.
#
# Finished...

# %%
descriptors_df
# Out:
#                                      HCDR1_APBS_pos  LCDR1_APBS_pos  \
# MPK190_VL_G43E_S69E                             0.0      269.097935
# MPK190_VL_S69E_A76S                             0.0      417.451709
# MPK190_VH_V2D_Q3E_K13Q_VL_R17E_A76S             0.0        0.000000
# MPK190_VH_V5E_VL_S69E_A76S                      0.0      147.922432
# MPK190_VH_Q3E_V5E_K13Q_VL_S69E_A76S             0.0        0.000000
# ...                                             ...             ...
# MPK190_VH_K13Q_VL_R17E                          0.0      328.455661
# MPK190_VH_V5E_VL_R17E_S69E_A76S                 0.0       97.363975
# MPK190_VH_K76Q_VL_S69E                          0.0      285.112868
# MPK190_VH_Q3E_K13Q_K76Q                         0.0       25.968654
# MPK190_VH_Q3E_V5E_K13Q                          0.0        0.000000
#
#                                      HCDR2_APBS_pos  LCDR2_APBS_pos  \
# MPK190_VL_G43E_S69E                      255.021623             0.0
# MPK190_VL_S69E_A76S                      497.657036             0.0
# MPK190_VH_V2D_Q3E_K13Q_VL_R17E_A76S        0.000000             0.0
# MPK190_VH_V5E_VL_S69E_A76S               319.805694             0.0
# MPK190_VH_Q3E_V5E_K13Q_VL_S69E_A76S       60.346228             0.0
# ...                                             ...             ...
# MPK190_VH_K13Q_VL_R17E                   329.169667             0.0
# MPK190_VH_V5E_VL_R17E_S69E_A76S           67.648184             0.0
# MPK190_VH_K76Q_VL_S69E                   232.949485             0.0
# MPK190_VH_Q3E_K13Q_K76Q                  149.336778             0.0
# MPK190_VH_Q3E_V5E_K13Q                   188.408243             0.0
#
#                                      HCDR3_APBS_pos  LCDR3_APBS_pos  \
# MPK190_VL_G43E_S69E                             0.0        0.000000
# MPK190_VL_S69E_A76S                             0.0      105.781582
# MPK190_VH_V2D_Q3E_K13Q_VL_R17E_A76S             0.0        0.000000
# MPK190_VH_V5E_VL_S69E_A76S                      0.0        0.000000
# MPK190_VH_Q3E_V5E_K13Q_VL_S69E_A76S             0.0        0.000000
# ...                                             ...             ...
# MPK190_VH_K13Q_VL_R17E                          0.0        0.000000
# MPK190_VH_V5E_VL_R17E_S69E_A76S                 0.0        0.000000
# MPK190_VH_K76Q_VL_S69E                          0.0        0.000000
# MPK190_VH_Q3E_K13Q_K76Q                         0.0        0.000000
# MPK190_VH_Q3E_V5E_K13Q                          0.0        0.000000
#
#                                      HFR1_APBS_pos  LFR1_APBS_pos  \
# MPK190_VL_G43E_S69E                      35.295604    3289.220535
# MPK190_VL_S69E_A76S                     106.250051    3767.202627
# MPK190_VH_V2D_Q3E_K13Q_VL_R17E_A76S       0.000000     865.873285
# MPK190_VH_V5E_VL_S69E_A76S               37.776915    2860.768331
# MPK190_VH_Q3E_V5E_K13Q_VL_S69E_A76S       0.000000    1198.803076
# ...                                            ...            ...
# MPK190_VH_K13Q_VL_R17E                    0.000000    2995.761587
# MPK190_VH_V5E_VL_R17E_S69E_A76S           0.000000    2414.073119
# MPK190_VH_K76Q_VL_S69E                   56.592228    3240.704964
# MPK190_VH_Q3E_K13Q_K76Q                   0.000000    1915.352822
# MPK190_VH_Q3E_V5E_K13Q                    0.000000    1597.797578
#
#                                      HFR2_APBS_pos  LFR2_APBS_pos  ...  \
# MPK190_VL_G43E_S69E                            0.0       0.000000  ...
# MPK190_VL_S69E_A76S                            0.0      76.020354  ...
# MPK190_VH_V2D_Q3E_K13Q_VL_R17E_A76S            0.0       0.000000  ...
# MPK190_VH_V5E_VL_S69E_A76S                     0.0       0.000000  ...
# MPK190_VH_Q3E_V5E_K13Q_VL_S69E_A76S            0.0       0.000000  ...
# ...                                            ...            ...  ...
# MPK190_VH_K13Q_VL_R17E                         0.0       0.000000  ...
# MPK190_VH_V5E_VL_R17E_S69E_A76S                0.0       0.000000  ...
# MPK190_VH_K76Q_VL_S69E                         0.0       0.000000  ...
# MPK190_VH_Q3E_K13Q_K76Q                        0.0       0.000000  ...
# MPK190_VH_Q3E_V5E_K13Q                         0.0       0.000000  ...
#
#                                      LFR2_APBS_net  HFR3_APBS_net  \
# MPK190_VL_G43E_S69E                    -281.869032            0.0
# MPK190_VL_S69E_A76S                      76.020354            0.0
# MPK190_VH_V2D_Q3E_K13Q_VL_R17E_A76S    -186.438243            0.0
# MPK190_VH_V5E_VL_S69E_A76S              -73.960327            0.0
# MPK190_VH_Q3E_V5E_K13Q_VL_S69E_A76S    -153.775253            0.0
# ...                                            ...            ...
# MPK190_VH_K13Q_VL_R17E                 -142.719992            0.0
# MPK190_VH_V5E_VL_R17E_S69E_A76S        -102.964691            0.0
# MPK190_VH_K76Q_VL_S69E                   -6.983839            0.0
# MPK190_VH_Q3E_K13Q_K76Q                -135.326359            0.0
# MPK190_VH_Q3E_V5E_K13Q                 -108.948805            0.0
#
#                                      LFR3_APBS_net  HFR4_APBS_net  \
# MPK190_VL_G43E_S69E                     897.538642     -88.505805
# MPK190_VL_S69E_A76S                    1163.696069     159.670027
# MPK190_VH_V2D_Q3E_K13Q_VL_R17E_A76S     323.800657    -138.881801
# MPK190_VH_V5E_VL_S69E_A76S              797.738823     -61.710067
# MPK190_VH_Q3E_V5E_K13Q_VL_S69E_A76S     470.180350     -86.685943
# ...                                            ...            ...
# MPK190_VH_K13Q_VL_R17E                  667.067620      20.644707
# MPK190_VH_V5E_VL_R17E_S69E_A76S         567.556964      39.277744
# MPK190_VH_K76Q_VL_S69E                  830.280099      -2.287860
# MPK190_VH_Q3E_K13Q_K76Q                 563.110904     -27.931578
# MPK190_VH_Q3E_V5E_K13Q                  554.203433     -46.671112
#
#                                      LFR4_APBS_net  HFR5_APBS_net  \
# MPK190_VL_G43E_S69E                     207.165896            0.0
# MPK190_VL_S69E_A76S                     362.248437            0.0
# MPK190_VH_V2D_Q3E_K13Q_VL_R17E_A76S    -291.374534            0.0
# MPK190_VH_V5E_VL_S69E_A76S              186.864528            0.0
# MPK190_VH_Q3E_V5E_K13Q_VL_S69E_A76S    -103.495685            0.0
# ...                                            ...            ...
# MPK190_VH_K13Q_VL_R17E                  225.461833            0.0
# MPK190_VH_V5E_VL_R17E_S69E_A76S          48.114342            0.0
# MPK190_VH_K76Q_VL_S69E                  265.978576            0.0
# MPK190_VH_Q3E_K13Q_K76Q                  70.059948            0.0
# MPK190_VH_Q3E_V5E_K13Q                  -36.003899            0.0
#
#                                      LFR5_APBS_net  CDR_APBS_pos  \
# MPK190_VL_G43E_S69E                            0.0   4999.230420
# MPK190_VL_S69E_A76S                            0.0   6655.977892
# MPK190_VH_V2D_Q3E_K13Q_VL_R17E_A76S            0.0   1488.163051
# MPK190_VH_V5E_VL_S69E_A76S                     0.0   4372.387762
# MPK190_VH_Q3E_V5E_K13Q_VL_S69E_A76S            0.0   1981.799804
# ...                                            ...           ...
# MPK190_VH_K13Q_VL_R17E                         0.0   4655.077177
# MPK190_VH_V5E_VL_R17E_S69E_A76S                0.0   3355.003214
# MPK190_VH_K76Q_VL_S69E                         0.0   5044.252482
# MPK190_VH_Q3E_K13Q_K76Q                        0.0   2829.864435
# MPK190_VH_Q3E_V5E_K13Q                         0.0   2516.405639
#
#                                      CDR_APBS_neg  CDR_APBS_net
# MPK190_VL_G43E_S69E                   -836.345814   4162.884606
# MPK190_VL_S69E_A76S                    -69.651674   6586.326218
# MPK190_VH_V2D_Q3E_K13Q_VL_R17E_A76S  -3031.466637  -1543.303586
# MPK190_VH_V5E_VL_S69E_A76S            -523.031781   3849.355981
# MPK190_VH_Q3E_V5E_K13Q_VL_S69E_A76S  -2165.939205   -184.139401
# ...                                           ...           ...
# MPK190_VH_K13Q_VL_R17E                -914.303892   3740.773285
# MPK190_VH_V5E_VL_R17E_S69E_A76S      -1195.801331   2159.201883
# MPK190_VH_K76Q_VL_S69E                -652.842244   4391.410238
# MPK190_VH_Q3E_K13Q_K76Q              -1127.692681   1702.171754
# MPK190_VH_Q3E_V5E_K13Q               -1605.641458    910.764181
#
# [141 rows x 51 columns]

# %% [markdown]
# ##### Load the table with mutations data and add name column

# %%
def name_mutation(row): 
    
    vh = row['Vh mutations']
    vl = row['Vl mutations']

    name ='MPK190'
    if vh: 
        vh = '_'.join(vh[1:-1].replace("'",'').replace(' ', '').split(','))
        name += f'_VH_{vh}'

    if vl: 
        vl = '_'.join(vl[1:-1].replace("'",'').replace(' ', '').split(','))
        name += f'_VL_{vl}'

    return name


def rename_mutation(row): 
    
    vh = row['Vh mutations']
    vl = row['Vl mutations']

    name ='MPK190'

    if vl: 
        vl = '-'.join(vl[1:-1].replace("'",'').replace(' ', '').split(','))
        name += f'-L-{vl}'
    if vh: 
        vh = '-'.join(vh[1:-1].replace("'",'').replace(' ', '').split(','))
        name += f'-H-{vh}'

    return name


mutations_df = pd.read_parquet(data_path/'mutations_data.parquet')
mutations_df = (mutations_df
                .drop_duplicates(subset = ['Vl mutations', 'Vh mutations'])
                .reset_index(drop=True)
                )
mutations_df.index = mutations_df.apply(name_mutation, axis = 1)
# create a dict to allow renaming
name_map = {name_mutation(row): rename_mutation(row) for _, row in mutations_df.iterrows()}

# %%
# get the heparin and organize  per the descriptors df
heparin = mutations_df['heparin binding'].loc[descriptors_df.index]
plate = mutations_df['plate'].loc[descriptors_df.index]
mutations_df = mutations_df.loc[descriptors_df.index]
assert (heparin.index == descriptors_df.index).mean() ==1

# %%
heparin_corr_both = (descriptors_df.corrwith(heparin)
                .dropna()
                .sort_values()
                )

heparin_corr_plate1 = (descriptors_df.loc[plate==1].corrwith(heparin)
                       .dropna()
                       .sort_values()
                       )

heparin_corr_plate2 = (descriptors_df.loc[plate==2].corrwith(heparin)
                       .dropna()
                       .sort_values()
                       )

# %%
fig, axes = plt.subplots(1,2,figsize = (8, 7))

ax = heparin_corr_plate1.plot(kind = 'barh', ax=axes[0])
ax.set(title = 'Plate 1', xlabel = 'Correlation')
ax = heparin_corr_plate2.plot(kind = 'barh', ax=axes[1])
ax.set(title = 'Plate 2', xlabel = 'Correlation')

sns.despine()
fig.suptitle('Correlation of Heparin ELISA with descriptors for MPK190')
plt.tight_layout()

# %% [markdown]
# ### Compare the data from plate 1 for predicted versus solved structure.

# %%
solved_descriptors_df = pd.read_parquet( data_path/'MPK190_antibodies_sheet1_descriptors.pq')
plate1_mutations_df = mutations_df.query('plate ==1').copy()
descriptors_df.index = descriptors_df.index.map(name_map)
plate1_descriptors_df = descriptors_df.loc[solved_descriptors_df.index]

# %%
corr_between_methods = (plate1_descriptors_df.corrwith(solved_descriptors_df)
                        .dropna()
                        .sort_values()
                        )
ax = corr_between_methods.plot(kind = 'barh', figsize = (6,7))
ax.set(xlabel='Correlation', title = 'Correlation between descriptors for plate 1 for predicted versus solved structures')

sns.despine()

# %%
cols = corr_between_methods.sort_values(ascending=False).index[:9]
fig, axes = plt.subplots(3,3, figsize = (8,7))
axes = np.ravel(axes)
for i, col in enumerate(cols): 
    sns.regplot(x=solved_descriptors_df[col], y=plate1_descriptors_df[col], ax = axes[i])

sns.despine()
fig.suptitle('Scatter plot of descriptors for MK190 calculated on Predicted versus Solved Structures')
plt.tight_layout()

# %%
corr_between_methods
# Out:
# LCDR3_APBS_neg    0.411259
# HCDR1_APBS_neg    0.608581
# LCDR3_APBS_net    0.862051
# LCDR3_APBS_pos    0.865843
# LCDR1_APBS_neg    0.872033
# LCDR1_APBS_pos    0.901654
# LCDR_APBS_neg     0.902406
# HCDR3_APBS_pos    0.906625
# HCDR1_APBS_pos    0.916689
# LCDR1_APBS_net    0.919061
# LCDR2_APBS_neg    0.924820
# LCDR_APBS_pos     0.938622
# HCDR1_APBS_net    0.942690
# LCDR_APBS_net     0.946013
# HCDR_APBS_neg     0.947663
# LCDR2_APBS_pos    0.952948
# HCDR3_APBS_net    0.954707
# HCDR3_APBS_neg    0.955751
# LCDR2_APBS_net    0.958734
# HCDR2_APBS_pos    0.959947
# HCDR_APBS_pos     0.960395
# LC_APBS_pos       0.961389
# HCDR2_APBS_net    0.962767
# LFR_APBS_pos      0.963710
# HCDR_APBS_net     0.972194
# LFR1_APBS_pos     0.972398
# TOTAL_APBS_pos    0.978779
# HFR1_APBS_pos     0.981209
# HFR1_APBS_neg     0.981367
# LC_APBS_net       0.982546
# HC_APBS_pos       0.983027
# HFR_APBS_pos      0.983027
# LFR_APBS_net      0.984653
# HFR_APBS_neg      0.985108
# HC_APBS_neg       0.985135
# TOTAL_APBS_neg    0.986577
# LFR1_APBS_neg     0.988651
# LFR1_APBS_net     0.988813
# TOTAL_APBS_net    0.989696
# HFR_APBS_net      0.989902
# HC_APBS_net       0.990057
# HFR1_APBS_net     0.990262
# LFR_APBS_neg      0.993943
# LC_APBS_neg       0.994069
# dtype: float64

# %% [markdown]
# ### Remarks:
# As we can see above, performing de novo prediction did not improve the performance, thus likely not due to the processing pipeline.
# We also get good correlation between many of the descriptors calculated on the solved-mutated structures versus de novo calculations.
